# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from classifier_selector import Classifier_selector
from sbs import SequentialBackwardSelection
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import Perceptron
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from mpa import mpa
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle

# %%
''' Testing phase '''
# Out:
# ' Testing phase '

# %%
classifier_selecting = Classifier_selector()

# %%
import numpy as np
from sklearn.datasets import make_blobs

def make_concentric_spheres(n_samples=1000, inner_radius=1.0, outer_radius=2.0, 
                          noise=0.1, random_state=None):
    """
    Generate a 3D dataset with two concentric spheres.
    
    Parameters:
    -----------
    n_samples : int, default=1000
        Total number of points split between the two spheres
    inner_radius : float, default=1.0
        Radius of the inner sphere
    outer_radius : float, default=2.0
        Radius of the outer sphere
    noise : float, default=0.1
        Standard deviation of Gaussian noise added to the data
    random_state : int or None, default=None
        Random seed for reproducibility
    
    Returns:
    --------
    X : ndarray of shape (n_samples, 3)
        The generated samples in 3D space
    y : ndarray of shape (n_samples,)
        The integer labels (0 or 1) for class membership
    """
    
    if random_state is not None:
        np.random.seed(random_state)
    
    # Split samples between inner and outer spheres
    n_inner = n_samples // 2
    n_outer = n_samples - n_inner
    
    # Generate random points on unit sphere using spherical coordinates
    phi = np.random.uniform(0, 2*np.pi, n_samples)
    theta = np.arccos(2 * np.random.uniform(0, 1, n_samples) - 1)
    
    # Create inner sphere points
    r_inner = inner_radius + np.random.normal(0, noise, n_inner)
    X_inner = np.vstack([
        r_inner * np.sin(theta[:n_inner]) * np.cos(phi[:n_inner]),
        r_inner * np.sin(theta[:n_inner]) * np.sin(phi[:n_inner]),
        r_inner * np.cos(theta[:n_inner])
    ]).T
    
    # Create outer sphere points
    r_outer = outer_radius + np.random.normal(0, noise, n_outer)
    X_outer = np.vstack([
        r_outer * np.sin(theta[n_inner:]) * np.cos(phi[n_inner:]),
        r_outer * np.sin(theta[n_inner:]) * np.sin(phi[n_inner:]),
        r_outer * np.cos(theta[n_inner:])
    ]).T
    
    # Combine the points
    X = np.vstack([X_inner, X_outer])
    y = np.hstack([np.zeros(n_inner), np.ones(n_outer)])
    
    # Shuffle the dataset
    shuffle_idx = np.random.permutation(n_samples)
    X = X[shuffle_idx]
    y = y[shuffle_idx]
    
    return X, y

X, y = make_concentric_spheres(n_samples=1000, 
                             inner_radius=1.0, 
                             outer_radius=2.0, 
                             noise=0.1, 
                             random_state=42)

X = pd.DataFrame(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
results_knn, scaler = classifier_selecting.optimize_classifier(X_train, X_test, y_train, y_test, 'knn')

print("\nBest Parameters:", results_knn['best_parameters'])
print("\nBest Cross-validation Score:", results_knn['best_score'])
print("\nFeature Importances:", results_knn['feature_importances'])
print("\nClassification Report:")
print(classification_report(y_test, results_knn['best_model'].predict(
    scaler.fit_transform(X_test))))
# Out:
# n_jobs = -1
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
#
# Best Parameters: {'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
#
# Best Cross-validation Score: 1.0
#
# Feature Importances: None
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        99
#          1.0       1.00      1.00      1.00       101
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200

# %%
knn = KNeighborsClassifier(**results_knn['best_parameters'])

sbs_knn = SequentialBackwardSelection(estimator=knn,
                                      min_features = 3,
                                      scoring_metric=accuracy_score,
                                      scale_features=True,
                                      verbose=True)
sbs_knn.fit(X_train, X_test, y_train, y_test)

# %%
results_perceptron, scaler = classifier_selecting.optimize_classifier(X_train, X_test, y_train, y_test, 'perceptron')

print("\nBest Parameters:", results_perceptron['best_parameters'])
print("\nBest Cross-validation Score:", results_perceptron['best_score'])
print("\nFeature Importances:", results_perceptron['feature_importances'])
print("\nClassification Report:")
print(classification_report(y_test, results_perceptron['best_model'].predict(
    scaler.fit_transform(X_test))))
# Out:
# Warning: Large parameter grid for perceptron. Switching to RandomizedSearchCV
# n_jobs = -1
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# /home/soulangel443/.local/share/mise/installs/python/latest/lib/python3.12/site-packages/sklearn/model_selection/_search.py:317: UserWarning: The total space of parameters 48 is smaller than n_iter=100. Running 48 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best Parameters: {'validation_fraction': 0.1, 'tol': 0.001, 'penalty': 'l2', 'max_iter': 500, 'early_stopping': True, 'alpha': 0.0001}
#
# Best Cross-validation Score: 0.5290341776749683
#
# Feature Importances: {0: 0.9322480509690928, 1: 1.1158227219096248, 2: 1.8457174631003739}
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.27      0.32        99
#          1.0       0.45      0.57      0.50       101
#
#     accuracy                           0.42       200
#    macro avg       0.42      0.42      0.41       200
# weighted avg       0.42      0.42      0.41       200

# %%
perceptron = Perceptron(**results_perceptron['best_parameters'])

sbs_perceptron = SequentialBackwardSelection(estimator=perceptron,
                                             min_features = 3,
                                             scoring_metric=accuracy_score,
                                             scale_features=True,
                                             verbose=True)
sbs_perceptron.fit(X_train, X_test, y_train, y_test)

# %%
results_rf, scaler = classifier_selecting.optimize_classifier(X_train, X_test, y_train, y_test, 'rf')

print("\nBest Parameters:", results_rf['best_parameters'])
print("\nBest Cross-validation Score:", results_rf['best_score'])
print("\nFeature Importances:", results_rf['feature_importances'])
print("\nClassification Report:")
print(classification_report(y_test, results_rf['best_model'].predict(
    scaler.fit_transform(X_test))))
# Out:
# Warning: Large parameter grid for rf. Switching to RandomizedSearchCV
# n_jobs = -1
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 50, 'criterion': 'entropy', 'class_weight': None, 'bootstrap': True}
#
# Best Cross-validation Score: 0.9925767823800633
#
# Feature Importances: {0: 0.33716481670642334, 1: 0.32610618854418993, 2: 0.3367289947493866}
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99        99
#          1.0       0.99      1.00      1.00       101
#
#     accuracy                           0.99       200
#    macro avg       1.00      0.99      0.99       200
# weighted avg       1.00      0.99      0.99       200

# %%
rf = RandomForestClassifier(**results_rf['best_parameters'])

sbs_rf = SequentialBackwardSelection(estimator=rf,
                                     min_features = 3,
                                     scoring_metric=accuracy_score,
                                     scale_features=True,
                                     verbose=True)
sbs_rf.fit(X_train, X_test, y_train, y_test)

# %%
results_dt, scaler = classifier_selecting.optimize_classifier(X_train, X_test, y_train, y_test, 'dt')

print("\nBest Parameters:", results_dt['best_parameters'])
print("\nBest Cross-validation Score:", results_dt['best_score'])
print("\nFeature Importances:", results_dt['feature_importances'])
print("\nClassification Report:")
print(classification_report(y_test, results_dt['best_model'].predict(
    scaler.fit_transform(X_test))))
# Out:
# Warning: Large parameter grid for dt. Switching to RandomizedSearchCV
# n_jobs = -1
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#
# Best Parameters: {'splitter': 'best', 'min_samples_split': 20, 'min_samples_leaf': 2, 'min_impurity_decrease': 0.01, 'max_features': None, 'max_depth': 30, 'criterion': 'entropy', 'class_weight': None}
#
# Best Cross-validation Score: 0.9889258179793539
#
# Feature Importances: {0: 0.34713493015334035, 1: 0.37483738035521935, 2: 0.2780276894914403}
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99        99
#          1.0       0.99      1.00      1.00       101
#
#     accuracy                           0.99       200
#    macro avg       1.00      0.99      0.99       200
# weighted avg       1.00      0.99      0.99       200

# %%
dt = DecisionTreeClassifier(**results_dt['best_parameters'])

sbs_dt = SequentialBackwardSelection(estimator=dt,
                                     min_features = 3,
                                     scoring_metric=accuracy_score,
                                     scale_features=True,
                                     verbose=True)
sbs_dt.fit(X_train, X_test, y_train, y_test)

# %%
results_svm, scaler = classifier_selecting.optimize_classifier(X_train, X_test, y_train, y_test, 'svm')

print("\nBest Parameters:", results_svm['best_parameters'])
print("\nBest Cross-validation Score:", results_svm['best_score'])
print("\nFeature Importances:", results_svm['feature_importances'])
print("\nClassification Report:")
print(classification_report(y_test, results_svm['best_model'].predict(
    scaler.fit_transform(X_test))))
# Out:
# Warning: Large parameter grid for svm. Switching to RandomizedSearchCV
# n_jobs = -1
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#
# Best Parameters: {'kernel': 'rbf', 'gamma': 0.1, 'degree': 2, 'coef0': 0.5, 'class_weight': None, 'C': 1}
#
# Best Cross-validation Score: 1.0
#
# Feature Importances: None
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        99
#          1.0       1.00      1.00      1.00       101
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200

# %%
svm = SVC(**results_svm['best_parameters'])

sbs_svm = SequentialBackwardSelection(estimator=svm,
                                      min_features = 3,
                                      scoring_metric=accuracy_score,
                                      scale_features=True,
                                      verbose=True)
sbs_svm.fit(X_train, X_test, y_train, y_test)

# %%
import numpy as np
import torch
from torch import nn
from torch.optim import Adam
from sklearn.base import BaseEstimator, ClassifierMixin
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import numpy as np
from sklearn.base import BaseEstimator, ClassifierMixin

class OptimizedBSpline(nn.Module):
    """Optimized B-spline with iterative De Boor algorithm"""
    def __init__(self, knots, degree=3):
        super().__init__()
        self.knots = knots
        self.degree = degree
        self.n_knots = len(knots)

    def _find_interval(self, t):
        """Find the knot interval index for each t value"""
        # Clamp t to valid range and find interval using searchsorted
        t_clamped = torch.clamp(t, self.knots[self.degree], self.knots[self.n_knots - self.degree - 1])
        i = torch.searchsorted(self.knots, t_clamped, right=True) - 1
        # Ensure i stays within valid bounds for degree-k spline
        return torch.clamp(i, self.degree, self.n_knots - self.degree - 1)

    def forward(self, t, control_points):
        """Iterative De Boor algorithm for B-spline evaluation"""
        batch_size = t.shape[0]
        n_control = len(control_points)
        k = self.degree

        # Find knot interval for each t
        interval = self._find_interval(t)  # Shape: [batch_size]

        # Initialize temporary control points for each t
        d = torch.zeros(batch_size, k + 1, device=t.device, dtype=t.dtype)
        for j in range(k + 1):
            idx = torch.clamp(interval - k + j, 0, n_control - 1)
            d[:, j] = control_points[idx]

        # Iterative De Boor computation
        for r in range(1, k + 1):
            for j in range(k, r - 1, -1):
                left_knot = self.knots[interval - k + j]
                right_knot = self.knots[interval - k + j + r]
                alpha = (t - left_knot) / (right_knot - left_knot + 1e-8)  # Add epsilon for stability
                d[:, j] = (1 - alpha) * d[:, j - 1] + alpha * d[:, j]

        return d[:, k]  # Final value for each t

class OptimizedTorchCubicSpline(nn.Module):
    def __init__(self, x, y):
        super().__init__()
        self.x = x
        self.y = nn.Parameter(y)
        n = len(x)
        self.register_buffer('knots', torch.cat([x[0].repeat(3), x[1:-1], x[-1].repeat(3)]))
        self.bspline = OptimizedBSpline(self.knots, degree=3)
        self.x_min = x[0]
        self.x_max = x[-1]

    def forward(self, t):
        return self.bspline(torch.clamp(t, self.x_min, self.x_max), self.y)

class OptimizedDifferentiablePchip(nn.Module):
    def __init__(self, x, y):
        super().__init__()
        self.x = x
        self.y = nn.Parameter(y)
        self.n = len(x) - 1

    def _compute_derivatives(self, y):
        dy = y[1:] - y[:-1]
        dx = self.x[1:] - self.x[:-1]
        slopes = dy / dx
        d = torch.zeros_like(y)
        for i in range(1, len(y)-1):
            if slopes[i-1] * slopes[i] > 0:
                w1 = 2*dx[i] + dx[i-1]
                w2 = dx[i] + 2*dx[i-1]
                d[i] = (w1 + w2) / (w1/slopes[i-1] + w2/slopes[i])
        d[0] = slopes[0]
        d[-1] = slopes[-1]
        return d

    def forward(self, t):
        idx = torch.clamp(torch.searchsorted(self.x, t) - 1, 0, self.n - 1)
        x0 = self.x[idx]
        x1 = self.x[idx + 1]
        y0 = self.y[idx]
        y1 = self.y[idx + 1]
        t_norm = (t - x0) / (x1 - x0)
        d = self._compute_derivatives(self.y)
        d0 = d[idx]
        d1 = d[idx + 1]
        t2 = t_norm * t_norm
        t3 = t2 * t_norm
        h00 = 2*t3 - 3*t2 + 1
        h10 = t3 - 2*t2 + t_norm
        h01 = -2*t3 + 3*t2
        h11 = t3 - t2
        dx_segment = x1 - x0
        return h00 * y0 + h10 * dx_segment * d0 + h01 * y1 + h11 * dx_segment * d1

class OptimizedPyTorchGradientSMPA(BaseEstimator, ClassifierMixin):
    def __init__(self, learning_rate=0.05, epochs=100, random_state=7, verbose=False,
                 lambda_reg=0.0001, patience=10, decay_factor=0.9, min_learning_rate=1e-6,
                 n_control_points=6, smoothing_factor=0.0001, spline_type='cubic',
                 device=None, track_history=False, optimizer_type='adam', scheduler_type='reduce_on_plateau'):
        self.learning_rate = learning_rate
        self.initial_learning_rate = learning_rate
        self.epochs = epochs
        self.random_state = random_state
        self.verbose = verbose
        self.lambda_reg = lambda_reg
        self.patience = patience
        self.decay_factor = decay_factor
        self.min_learning_rate = min_learning_rate
        self.n_control_points = n_control_points
        self.smoothing_factor = smoothing_factor
        self.spline_type = spline_type
        self.device = device if device is not None else ('cuda' if torch.cuda.is_available() else 'cpu')
        self.track_history = track_history
        self.optimizer_type = optimizer_type
        self.scheduler_type = scheduler_type

        if spline_type not in ['cubic', 'pchip']:
            raise ValueError("spline_type must be 'cubic' or 'pchip'")
        torch.manual_seed(random_state)
        np.random.seed(random_state)

    def _to_tensor(self, data, dtype=torch.float32):
        if isinstance(data, torch.Tensor):
            return data.to(self.device, dtype=dtype, non_blocking=True)
        return torch.tensor(data, dtype=dtype, device=self.device)

    def _calculate_class_means(self, X, y):
        mask_1 = y == 1
        self.m1 = torch.mean(X[mask_1], dim=0)
        self.m0 = torch.mean(X[~mask_1], dim=0)

    def _initialize_control_points(self, X):
        n_features = X.shape[1] - 1
        self.spline_models = nn.ModuleList()
        for i in range(n_features):
            x_min, x_max = X[:, i].min().item(), X[:, i].max().item()
            control_x = torch.linspace(x_min, x_max, self.n_control_points, device=self.device)
            y_min, y_max = X[:, -1].min().item(), X[:, -1].max().item()
            y_mid = (self.m0[-1] + self.m1[-1]) / 2
            y_range = y_max - y_min
            control_y = torch.empty(self.n_control_points, device=self.device).uniform_(
                y_mid - y_range * 0.05, y_mid + y_range * 0.05
            )
            if self.spline_type == 'cubic':
                spline = OptimizedTorchCubicSpline(control_x, control_y).to(self.device)
            else:
                spline = OptimizedDifferentiablePchip(control_x, control_y).to(self.device)
            self.spline_models.append(spline)
        self.initial_control_points = [(m.x.clone(), m.y.clone()) for m in self.spline_models]

    def _calculate_displacement(self, X):
        total_spline = sum(spline(X[:, i]) for i, spline in enumerate(self.spline_models))
        return X[:, -1] - total_spline

    def _update_pseudo_labels(self, X, y):
        m1_displacement = self._calculate_displacement(self.m1.unsqueeze(0))[0]
        self.class_1_pseudo = 1 if m1_displacement > 0 else -1
        self.class_0_pseudo = -self.class_1_pseudo
        return torch.where(y == 1, self.class_1_pseudo, self.class_0_pseudo)

    def _create_optimizer_and_scheduler(self):
        params = [p for spline in self.spline_models for p in spline.parameters()]
        if self.optimizer_type.lower() == 'adam':
            optimizer = torch.optim.Adam(params, lr=self.initial_learning_rate)
        else:
            optimizer = torch.optim.SGD(params, lr=self.initial_learning_rate)
        if self.scheduler_type.lower() == 'reduce_on_plateau':
            scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
                optimizer, mode='min', factor=self.decay_factor,
                patience=self.patience, min_lr=self.min_learning_rate)
        elif self.scheduler_type.lower() == 'step':
            scheduler = torch.optim.lr_scheduler.StepLR(
                optimizer, step_size=self.patience, gamma=self.decay_factor
            )
        else:
            scheduler = None
        return optimizer, scheduler

    def fit(self, X, y):
        if not set(np.unique(y)).issubset({0, 1}):
            raise ValueError("Labels must be 0 and 1")
        if X.shape[1] < 2:
            raise ValueError("At least 2 features required")

        X_tensor = self._to_tensor(X)
        y_tensor = self._to_tensor(y, dtype=torch.long)

        with torch.no_grad():
            self._calculate_class_means(X_tensor, y_tensor)
            self._initialize_control_points(X_tensor)

        optimizer, scheduler = self._create_optimizer_and_scheduler()

        best_error = float('inf')
        best_control_ys = [spline.y.clone() for spline in self.spline_models]
        best_class_1_pseudo = None

        if self.track_history:
            self.error_history_ = []
            self.control_point_history = [self.initial_control_points]

        for epoch in range(self.epochs):
            pseudo_labels = self._update_pseudo_labels(X_tensor, y_tensor)
            displacements = self._calculate_displacement(X_tensor)

            errors = displacements * pseudo_labels <= 0
            error_count = errors.sum().item()

            if self.verbose and epoch % 5 == 0:
                current_lr = optimizer.param_groups[0]['lr']
                print(f"Epoch {epoch}: Errors = {error_count}, LR = {current_lr:.6f}")

            if error_count < best_error:
                best_error = error_count
                best_control_ys = [spline.y.clone() for spline in self.spline_models]
                best_class_1_pseudo = self.class_1_pseudo
                self.best_epoch = epoch
                if error_count == 0 and epoch > 10:
                    if self.verbose:
                        print(f"Perfect separation achieved at epoch {epoch}")
                    break

            if self.track_history:
                self.error_history_.append(error_count)
                self.control_point_history.append(
                    [(s.x.clone().cpu().numpy(), s.y.clone().detach().cpu().numpy())
                     for s in self.spline_models]
                )

            if error_count == 0:
                continue

            error_indices = torch.where(errors)[0]
            X_err = X_tensor[error_indices]
            y_err = y_tensor[error_indices]
            ti = torch.where(y_err == 1, 1, -1)

            spline_values = sum(spline(X_err[:, i]) for i, spline in enumerate(self.spline_models))
            loss = torch.mean(torch.relu(1.0 - ti * self.class_1_pseudo * (X_err[:, -1] - spline_values)))

            if self.lambda_reg > 0:
                smoothness_penalty = 0
                for spline in self.spline_models:
                    y_diff = spline.y[1:] - spline.y[:-1]
                    x_diff = spline.x[1:] - spline.x[:-1]
                    smoothness_penalty += torch.mean((y_diff / (x_diff + 1e-8))**2)
                loss += self.lambda_reg * smoothness_penalty

            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            optimizer.step()

            if scheduler is None:
                if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                    scheduler.step(error_count)
                else:
                    scheduler.step()
                if optimizer.param_groups[0]['lr'] <= self.min_learning_rate:
                    if self.verbose:
                        print(f"Minimum learning rate reached at epoch {epoch}")
                    break

        for spline, best_y in zip(self.spline_models, best_control_ys):
            spline.y.data = best_y
        self.class_1_pseudo = best_class_1_pseudo
        return self

    def predict(self, X):
        X_tensor = self._to_tensor(X)
        displacements = self._calculate_displacement(X_tensor)
        predictions = torch.where(displacements > 0,
                                torch.tensor(1 if self.class_1_pseudo > 0 else 0, device=self.device),
                                torch.tensor(0 if self.class_1_pseudo > 0 else 1, device=self.device))
        return predictions.cpu().numpy()

    def predict_proba(self, X):
        X_tensor = self._to_tensor(X)
        displacements = self._calculate_displacement(X_tensor)
        raw_probs = 1 / (1 + torch.exp(-displacements * self.class_1_pseudo * 0.5))
        if self.class_1_pseudo > 0:
            probs = torch.column_stack([1 - raw_probs, raw_probs])
        else:
            probs = torch.column_stack([raw_probs, 1 - raw_probs])
        return probs.cpu().numpy()

    def plot_convergence(self, figsize=(10, 4)):
        if not self.track_history or not hasattr(self, 'error_history_'):
            print("Convergence plotting requires track_history=True and a fitted model.")
            return None

        fig, ax = plt.subplots(figsize=figsize)
        ax.plot(self.error_history_, 'b-', label='Errors')
        ax.set_title('Error Convergence')
        ax.set_xlabel('Epoch')
        ax.set_ylabel('Number of Errors')
        ax.grid(True)
        ax.legend()
        plt.tight_layout()
        return fig

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

def reorder_least_correlated_feature(X, standardize=True, feature_order=None, scaler=None):
    """
    Reorder X based on correlation or a provided feature order, applying standardization if specified.

    Parameters:
    - X: numpy array or pandas DataFrame
    - standardize: bool
    - feature_order: list, optional order from training set (default: None, compute from X)
    - scaler: StandardScaler instance, optional for test set standardization (default: None)

    Returns:
    - X_reordered, feature_order, scaler (scaler is None if feature_order is provided and not used)
    """
    is_dataframe = isinstance(X, pd.DataFrame)
    if is_dataframe:
        column_names = X.columns
        X_np = X.to_numpy()
    else:
        X_np = np.asarray(X)

    if feature_order is None:
        # Training case: compute order and standardize
        if standardize:
            scaler = StandardScaler()
            X_scaled = scaler.fit_transform(X_np)
        else:
            X_scaled = X_np.copy()

        corr_matrix = np.abs(np.corrcoef(X_scaled, rowvar=False))
        n_features = X_np.shape[1]
        avg_corr = (np.sum(corr_matrix, axis=1) - np.diag(corr_matrix)) / (n_features - 1)
        target_idx = np.argmin(avg_corr)
        feature_order = list(range(n_features))
        feature_order.pop(target_idx)
        feature_order.append(target_idx)

        if is_dataframe:
            X_reordered = pd.DataFrame(X_scaled[:, feature_order],
                                      columns=[column_names[i] for i in feature_order])
        else:
            X_reordered = X_scaled[:, feature_order]
    else:
        # Test case: use provided order and standardize with provided scaler if given
        if standardize and scaler is not None:
            X_scaled = scaler.transform(X_np)
            if is_dataframe:
                X_reordered = pd.DataFrame(X_scaled[:, feature_order],
                                         columns=[column_names[i] for i in feature_order])
            else:
                X_reordered = X_scaled[:, feature_order]
        else:
            # No standardization, just reorder
            if is_dataframe:
                X_reordered = X.iloc[:, feature_order]
            else:
                X_reordered = X_np[:, feature_order]
        scaler = None  # No new scaler created

    return X_reordered, feature_order, scaler

# Updated usage
X_train_reordered, feature_order, scaler = reorder_least_correlated_feature(X_train)
print(f"Train - Means: {X_train_reordered.mean(axis=0).round(2)}, "
      f"Stds: {X_train_reordered.std(axis=0).round(2)}")
X_test_reordered, _, _ = reorder_least_correlated_feature(X_test, feature_order=feature_order, scaler=scaler)
print(f"Test - Means: {X_test_reordered.mean(axis=0).round(2)}, "
      f"Stds: {X_test_reordered.std(axis=0).round(2)}")
# Out:
# Train - Means: 0    0.0
# 1    0.0
# 2   -0.0
# dtype: float64, Stds: 0    1.0
# 1    1.0
# 2    1.0
# dtype: float64
# Test - Means: 0   -0.10
# 1   -0.04
# 2   -0.03
# dtype: float64, Stds: 0    0.94
# 1    1.02
# 2    1.05
# dtype: float64

# %%
X_train_reordered = X_train_reordered.to_numpy()
X_test_reordered = X_test_reordered.to_numpy()

# %%
type(X_train_reordered)
type(y_train)
# Out:
# numpy.ndarray

# %%
model = OptimizedPyTorchGradientSMPA(
    learning_rate=0.01,
    epochs=200,
    n_control_points=8,
    spline_type='pchip',
    device='cpu',  # Will use GPU if available
    track_history=True,
    random_state = 44,
    decay_factor=0.99
)

# Train model
model.fit(X_train_reordered, y_train)

model.plot_convergence()
# Out:
# /tmp/ipykernel_27111/3442450973.py:83: UserWarning: torch.searchsorted(): input value tensor is non-contiguous, this will lower the performance due to extra data copy when converting non-contiguous tensor to contiguous, please use contiguous input value tensor if possible. This message will only appear once per program. (Triggered internally at ../aten/src/ATen/native/BucketizationUtils.h:32.)
#   idx = torch.clamp(torch.searchsorted(self.x, t) - 1, 0, self.n - 1)

# %%
from sklearn.metrics import f1_score

score = model.score(X_test_reordered, y_test)
print(score)
f1 = f1_score(y_test, model.predict(X_test_reordered))
print(f1)
from sklearn.metrics import classification_report
print(classification_report(y_test,model.predict(X_test_reordered)))
cr = classification_report(y_test, model.predict(X_test_reordered))
# Out:
# 0.55
# 0.55
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.56      0.55        99
#          1.0       0.56      0.54      0.55       101
#
#     accuracy                           0.55       200
#    macro avg       0.55      0.55      0.55       200
# weighted avg       0.55      0.55      0.55       200

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# %%
param_grid = {
                'learning_rate': [0.01, 0.001, 0.02, 0.00001],           # Range to balance step size
                'epochs': [300],                         # Enough iterations to converge
                'n_control_points': [5, 8, 9, 15, 20],              # More points to capture wiggles
                'spline_type': ['pchip','cubic'],            # Test both spline types
                'patience': [15],                             # Fixed patience for consistency
                'decay_factor': [0.99],                        # Fixed decay for simplicity
                'min_learning_rate': [1.e-6],
                'smoothing_factor': [0.00000001, 0.000001]

}
smpa = OptimizedPyTorchGradientSMPA(random_state=12, track_history=True, device='cpu')
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=4)
grid_search = GridSearchCV(smpa, param_grid, cv=cv, scoring='f1', n_jobs=-1, verbose=3)
grid_search.fit(X_train_reordered, y_train)
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# /tmp/ipykernel_27111/3442450973.py:83: UserWarning: torch.searchsorted(): input value tensor is non-contiguous, this will lower the performance due to extra data copy when converting non-contiguous tensor to contiguous, please use contiguous input value tensor if possible. This message will only appear once per program. (Triggered internally at ../aten/src/ATen/native/BucketizationUtils.h:32.)
# /tmp/ipykernel_27111/3442450973.py:83: UserWarning: torch.searchsorted(): input value tensor is non-contiguous, this will lower the performance due to extra data copy when converting non-contiguous tensor to contiguous, please use contiguous input value tensor if possible. This message will only appear once per program. (Triggered internally at ../aten/src/ATen/native/BucketizationUtils.h:32.)
# /tmp/ipykernel_27111/3442450973.py:83: UserWarning: torch.searchsorted(): input value tensor is non-contiguous, this will lower the performance due to extra data copy when converting non-contiguous tensor to contiguous, please use contiguous input value tensor if possible. This message will only appear once per program. (Triggered internally at ../aten/src/ATen/native/BucketizationUtils.h:32.)
# /tmp/ipykernel_27111/3442450973.py:83: UserWarning: torch.searchsorted(): input value tensor is non-contiguous, this will lower the performance due to extra data copy when converting non-contiguous tensor to contiguous, please use contiguous input value tensor if possible. This message will only appear once per program. (Triggered internally at ../aten/src/ATen/native/BucketizationUtils.h:32.)
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.534 total time=   3.2s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.471 total time=   3.8s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.575 total time=   3.9s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.538 total time=   3.6s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.510 total time=   2.6s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.534 total time=   5.1s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.286 total time=   5.4s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.575 total time=   5.5s
# /tmp/ipykernel_27111/3442450973.py:83: UserWarning: torch.searchsorted(): input value tensor is non-contiguous, this will lower the performance due to extra data copy when converting non-contiguous tensor to contiguous, please use contiguous input value tensor if possible. This message will only appear once per program. (Triggered internally at ../aten/src/ATen/native/BucketizationUtils.h:32.)
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.440 total time=   2.6s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.523 total time=   5.9s
# /tmp/ipykernel_27111/3442450973.py:83: UserWarning: torch.searchsorted(): input value tensor is non-contiguous, this will lower the performance due to extra data copy when converting non-contiguous tensor to contiguous, please use contiguous input value tensor if possible. This message will only appear once per program. (Triggered internally at ../aten/src/ATen/native/BucketizationUtils.h:32.)
# /tmp/ipykernel_27111/3442450973.py:83: UserWarning: torch.searchsorted(): input value tensor is non-contiguous, this will lower the performance due to extra data copy when converting non-contiguous tensor to contiguous, please use contiguous input value tensor if possible. This message will only appear once per program. (Triggered internally at ../aten/src/ATen/native/BucketizationUtils.h:32.)
# /tmp/ipykernel_27111/3442450973.py:83: UserWarning: torch.searchsorted(): input value tensor is non-contiguous, this will lower the performance due to extra data copy when converting non-contiguous tensor to contiguous, please use contiguous input value tensor if possible. This message will only appear once per program. (Triggered internally at ../aten/src/ATen/native/BucketizationUtils.h:32.)
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.535 total time=   3.7s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.543 total time=   3.3s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.585 total time=   2.5s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.581 total time=   4.2s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.510 total time=   2.6s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.283 total time=   4.8s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.067 total time=   4.2s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.500 total time=   5.6s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.548 total time=   2.5s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.571 total time=   5.4s
# /tmp/ipykernel_27111/3442450973.py:83: UserWarning: torch.searchsorted(): input value tensor is non-contiguous, this will lower the performance due to extra data copy when converting non-contiguous tensor to contiguous, please use contiguous input value tensor if possible. This message will only appear once per program. (Triggered internally at ../aten/src/ATen/native/BucketizationUtils.h:32.)
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.503 total time=   2.6s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.521 total time=   7.4s
# /tmp/ipykernel_27111/3442450973.py:83: UserWarning: torch.searchsorted(): input value tensor is non-contiguous, this will lower the performance due to extra data copy when converting non-contiguous tensor to contiguous, please use contiguous input value tensor if possible. This message will only appear once per program. (Triggered internally at ../aten/src/ATen/native/BucketizationUtils.h:32.)
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.590 total time=   2.6s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.587 total time=   7.7s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.674 total time=   4.2s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.626 total time=   3.9s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.513 total time=   3.0s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.648 total time=   5.1s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.655 total time=   4.8s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.488 total time=   2.3s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.503 total time=   2.2s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.663 total time=   5.4s
# /tmp/ipykernel_27111/3442450973.py:83: UserWarning: torch.searchsorted(): input value tensor is non-contiguous, this will lower the performance due to extra data copy when converting non-contiguous tensor to contiguous, please use contiguous input value tensor if possible. This message will only appear once per program. (Triggered internally at ../aten/src/ATen/native/BucketizationUtils.h:32.)
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.585 total time=   5.4s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.090 total time=  11.4s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.595 total time=   2.4s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.578 total time=   3.0s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.526 total time=   2.8s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.519 total time=   2.4s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.615 total time=   5.4s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.626 total time=   4.7s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.539 total time=  16.4s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.648 total time=   6.6s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.697 total time=   3.7s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.695 total time=   4.4s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.704 total time=   7.0s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.629 total time=   3.7s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.587 total time=   3.1s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.588 total time=   3.1s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.675 total time=   4.2s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.523 total time=   7.2s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.535 total time=   2.3s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.655 total time=   9.4s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.526 total time=   4.5s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.667 total time=   7.5s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.471 total time=   5.4s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.670 total time=   4.5s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.659 total time=   5.2s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.547 total time=   3.0s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.585 total time=   4.2s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.675 total time=   4.6s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.543 total time=   3.9s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.619 total time=   5.6s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.626 total time=   4.0s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.613 total time=   3.9s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.604 total time=   3.6s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.609 total time=   3.8s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.539 total time=   3.3s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.584 total time=   4.1s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.652 total time=   9.9s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.493 total time=   6.9s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.566 total time=   9.6s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.494 total time=   3.4s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.675 total time=   7.0s
# /tmp/ipykernel_27111/3442450973.py:83: UserWarning: torch.searchsorted(): input value tensor is non-contiguous, this will lower the performance due to extra data copy when converting non-contiguous tensor to contiguous, please use contiguous input value tensor if possible. This message will only appear once per program. (Triggered internally at ../aten/src/ATen/native/BucketizationUtils.h:32.)
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.629 total time=   3.6s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.613 total time=   3.9s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.623 total time=   3.9s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.539 total time=   7.5s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.594 total time=   4.5s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.550 total time=   4.6s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.613 total time=  11.7s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.641 total time=   3.6s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.630 total time=   6.9s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.481 total time=   4.6s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.585 total time=   3.6s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.539 total time=   3.9s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.559 total time=   3.8s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.643 total time=  10.7s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.560 total time=   3.5s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.601 total time=   9.5s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.523 total time=   3.8s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.675 total time=   3.6s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.594 total time=   6.2s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.543 total time=   2.0s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.516 total time=   5.2s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.575 total time=   2.1s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.510 total time=   1.9s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.571 total time=   4.0s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.524 total time=   3.8s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.538 total time=   1.9s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.452 total time=   2.1s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.581 total time=  11.9s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.543 total time=   2.1s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.601 total time=  10.4s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.544 total time=   3.6s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.288 total time=   3.7s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.566 total time=   2.1s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.543 total time=   6.7s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.534 total time=   4.3s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.529 total time=   4.1s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.520 total time=   9.7s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.535 total time=   2.0s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.01, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.539 total time=  16.4s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.067 total time=   5.4s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.453 total time=   3.1s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.590 total time=   2.4s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.510 total time=   4.3s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.588 total time=   3.8s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.588 total time=   2.3s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.510 total time=   2.5s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.544 total time=   4.3s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.533 total time=   4.6s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.443 total time=   2.9s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.596 total time=   2.1s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.659 total time=   4.0s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.513 total time=   2.6s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.611 total time=   3.6s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.663 total time=   3.8s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.636 total time=   4.0s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.607 total time=   5.1s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.506 total time=   2.4s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.578 total time=   4.8s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.481 total time=   3.7s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.648 total time=   4.1s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.497 total time=   8.7s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.682 total time=   3.6s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.640 total time=   3.6s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.587 total time=   3.0s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.600 total time=   2.9s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.695 total time=   4.0s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.526 total time=   3.2s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.491 total time=   3.5s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.681 total time=   6.1s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.595 total time=   2.4s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.582 total time=   2.8s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.688 total time=   3.6s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.697 total time=   3.8s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.678 total time=   4.2s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.679 total time=   3.6s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.536 total time=   3.0s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.566 total time=   2.7s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.560 total time=  17.4s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.678 total time=   3.8s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.561 total time=   3.1s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.682 total time=   3.9s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.687 total time=   3.6s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.671 total time=   3.6s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.513 total time=   8.1s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.667 total time=   4.1s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.068 total time=  18.8s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.585 total time=   3.8s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.671 total time=  11.3s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.630 total time=   3.7s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.591 total time=   3.5s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.615 total time=   4.0s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.614 total time=   3.8s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.630 total time=   4.0s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.609 total time=   3.6s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.584 total time=   6.0s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.526 total time=  11.0s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.549 total time=   3.3s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.484 total time=   3.0s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.536 total time=   8.1s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.466 total time=   7.0s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.582 total time=   3.7s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.667 total time=   3.6s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.627 total time=   4.1s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.662 total time=   5.6s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.554 total time=   3.5s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.530 total time=   3.7s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.583 total time=   4.2s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.593 total time=   4.5s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.487 total time=   4.0s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.568 total time=   3.7s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.585 total time=   4.8s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.557 total time=   3.8s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.606 total time=   8.1s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.542 total time=   4.1s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.556 total time=   3.5s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.578 total time=   4.4s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.642 total time=  11.9s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.647 total time=   8.8s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.490 total time=   4.4s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.601 total time=   6.4s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.543 total time=   2.3s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.520 total time=   6.7s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.611 total time=   3.6s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.491 total time=   1.8s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.588 total time=   3.9s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.503 total time=   1.9s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.456 total time=   2.1s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.624 total time=   7.1s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.581 total time=   5.0s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.555 total time=  20.7s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.543 total time=   2.1s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.001, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.577 total time=   6.5s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.581 total time=   2.0s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.538 total time=   2.0s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.551 total time=   4.0s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.067 total time=   3.7s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.576 total time=   4.5s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.524 total time=   4.4s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.590 total time=   2.4s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.588 total time=   2.2s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.549 total time=   4.3s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.264 total time=   4.0s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.503 total time=   2.3s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.560 total time=   4.0s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=0.02, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.578 total time=   9.6s
# ...
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.588 total time=   2.3s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.523 total time=   2.2s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.681 total time=   4.0s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.659 total time=   4.0s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.542 total time=   2.2s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.590 total time=   3.1s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.465 total time=   2.1s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=5, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.526 total time=  10.7s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.595 total time=   2.3s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.587 total time=   2.8s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.626 total time=   3.9s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.648 total time=   8.6s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.629 total time=   3.8s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.517 total time=   3.1s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.655 total time=   4.3s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.681 total time=   4.5s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.648 total time=   5.2s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.615 total time=   7.7s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.523 total time=   3.1s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.522 total time=   2.3s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.595 total time=   2.5s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.655 total time=   4.4s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.582 total time=   2.8s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=8, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.626 total time=  10.6s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.659 total time=   4.3s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.635 total time=   4.2s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.497 total time=   3.8s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.578 total time=   4.5s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.517 total time=   5.1s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.655 total time=   4.6s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.678 total time=   6.4s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.547 total time=   3.3s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.693 total time=   6.0s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.722 total time=   5.4s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.539 total time=   4.4s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.601 total time=   4.9s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.619 total time=   6.4s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.646 total time=   4.9s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.685 total time=  10.9s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.503 total time=   5.3s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=9, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.667 total time=   7.5s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.617 total time=   4.2s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.561 total time=   8.0s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.636 total time=   3.8s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.581 total time=   4.0s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.600 total time=   4.1s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.630 total time=   4.5s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.509 total time=   3.9s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.630 total time=   4.1s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.654 total time=   3.9s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.614 total time=   4.1s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.539 total time=   7.0s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.646 total time=   5.2s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.556 total time=   3.7s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.659 total time=   8.1s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.520 total time=   4.8s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.599 total time=   6.9s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.632 total time=   4.5s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.506 total time=   5.6s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.571 total time=   4.2s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.615 total time=   4.4s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.514 total time=   5.0s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=pchip;, score=0.593 total time=   8.8s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.581 total time=   5.0s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-08, spline_type=cubic;, score=0.616 total time=  16.8s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.593 total time=   4.8s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.550 total time=   3.7s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.520 total time=   4.1s
# [CV 4/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.525 total time=   3.0s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.596 total time=   3.8s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.500 total time=   4.7s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.570 total time=   3.5s
# [CV 5/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=15, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.522 total time=  15.2s
# [CV 1/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.671 total time=   4.8s
# [CV 2/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=pchip;, score=0.585 total time=   7.2s
# [CV 3/5] END decay_factor=0.99, epochs=300, learning_rate=1e-05, min_learning_rate=1e-06, n_control_points=20, patience=15, smoothing_factor=1e-06, spline_type=cubic;, score=0.571 total time=   5.0s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=4, shuffle=True),
#              estimator=OptimizedPyTorchGradientSMPA(device='cpu',
#                                                     random_state=12,
#                                                     track_history=True),
#              n_jobs=-1,
#              param_grid={'decay_factor': [0.99], 'epochs': [300],
#                          'learning_rate': [0.01, 0.001, 0.02, 1e-05],
#                          'min_learning_rate': [1e-06],
#                          'n_control_points': [5, 8, 9, 15, 20],
#                          'patience': [15], 'smoothing_factor': [1e-08, 1e-06],
#                          'spline_type': ['pchip', 'cubic']},
#              scoring='f1', verbose=3)

# %%
cr = classification_report(y_test, grid_search.best_estimator_.predict(X_test_reordered))
print("Classification report \n", cr)
print("Best CV score: ", grid_search.best_score_)

fig = grid_search.best_estimator_.plot_convergence()
plt.show()
# Out:
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.70      0.57      0.63        99
#          1.0       0.64      0.76      0.70       101
#
#     accuracy                           0.67       200
#    macro avg       0.67      0.66      0.66       200
# weighted avg       0.67      0.67      0.66       200
#
# Best CV score:  0.6824223773369676

# %%
grid_search.best_params_
# Out:
# {'decay_factor': 0.99,
#  'epochs': 300,
#  'learning_rate': 0.001,
#  'min_learning_rate': 1e-06,
#  'n_control_points': 9,
#  'patience': 15,
#  'smoothing_factor': 1e-08,
#  'spline_type': 'cubic'}

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

def plot_spline_pairs(model, X, y, feature_names=None, figsize=(12, 8)):
    """
    Plot feature vs. target feature with fitted splines for an OptimizedPyTorchGradientSMPA model.

    Parameters:
    - model: Trained OptimizedPyTorchGradientSMPA instance
    - X: Input data (numpy array or torch tensor), shape [n_samples, n_features]
    - y: Target labels (numpy array or torch tensor), shape [n_samples]
    - feature_names: Optional list of feature names for labeling (length n_features)
    - figsize: Tuple for figure size (width, height)
    """
    # Convert inputs to numpy for plotting
    if isinstance(X, torch.Tensor):
        X = X.cpu().detach().numpy()
    if isinstance(y, torch.Tensor):
        y = y.cpu().detach().numpy()

    n_features = X.shape[1]
    target_idx = n_features - 1
    n_plots = n_features - 1

    # Diagnostic: Print min/max of each feature
    print("Feature ranges in X passed to plot_spline_pairs:")
    for i in range(n_features):
        print(f"{'Target' if i == target_idx else f'Feature {i}'}: "
              f"min={X[:, i].min():.2f}, max={X[:, i].max():.2f}")

    # Set up figure
    rows = int(np.ceil(n_plots / 2))
    cols = min(2, n_plots)
    fig, axes = plt.subplots(rows, cols, figsize=figsize, squeeze=False)
    axes = axes.flatten()

    # Default feature names if none provided
    if feature_names is None:
        feature_names = [f"Feature {i}" for i in range(n_features)]

    # Move spline models to CPU for evaluation
    model_device = model.device
    for spline in model.spline_models:
        spline.to('cpu')

    for i in range(n_plots):
        ax = axes[i]
        feature = X[:, i]
        target = X[:, target_idx]

        # Scatter plot: feature vs. target, colored by class
        scatter = ax.scatter(feature, target, c=y, cmap='viridis', alpha=0.6)
        plt.colorbar(scatter, ax=ax, label='Class')

        # Generate points for spline evaluation (in standardized scale)
        x_range = np.linspace(feature.min(), feature.max(), 200)
        x_tensor = torch.tensor(x_range, dtype=torch.float32)

        # Evaluate the spline
        spline_output = model.spline_models[i](x_tensor).detach().numpy()

        # Plot the spline
        ax.plot(x_range, spline_output, 'r-', label='Fitted Spline', linewidth=2)

        # Reference line
        ax.axhline(0, color='k', linestyle='--', alpha=0.3, label='Zero Line')

        # Labeling
        ax.set_xlabel(feature_names[i])
        ax.set_ylabel(feature_names[target_idx])
        ax.set_title(f'{feature_names[i]} vs. {feature_names[target_idx]}')
        ax.legend()

    # Hide unused subplots
    for j in range(n_plots, len(axes)):
        axes[j].axis('off')

    plt.tight_layout()
    plt.show()

    # Restore spline models to original device
    for spline in model.spline_models:
        spline.to(model_device)

# %%
plot_spline_pairs(grid_search.best_estimator_, X_train_reordered, y_train)
# Out:
# Feature ranges in X passed to plot_spline_pairs:
# Feature 0: min=-2.33, max=2.32
# Feature 1: min=-2.35, max=2.25
# Target: min=-2.42, max=2.50
