# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from classifier_selector import Classifier_selector
from sbs import SequentialBackwardSelection
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import Perceptron
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from mpa import mpa
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle

# %%
''' Testing phase '''
# Out:
# ' Testing phase '

# %%
classifier_selecting = Classifier_selector()

# %%
sonar_df = pd.read_csv("./Datasets/sonar.csv", header = None)
num_features = sonar_df.shape[1] - 1  # Assuming the last column is the label
feature_names = [f'feature{i+1}' for i in range(num_features)] + ['label']
sonar_df.columns = feature_names
dict1 = {'R':0,'M':1}
sonar_df = sonar_df.replace({'label':dict1})
sonar_df['label'] = sonar_df['label'].apply(pd.to_numeric, errors = 'coerce')
sonar_df = shuffle(sonar_df, random_state=42)
# Out:
# /tmp/ipykernel_60461/2772083269.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sonar_df = sonar_df.replace({'label':dict1})

# %%
sonar_df.head()
# Out:
#      feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 161    0.0305    0.0363    0.0214    0.0227    0.0456    0.0665    0.0939
# 15     0.0298    0.0615    0.0650    0.0921    0.1615    0.2294    0.2176
# 73     0.0139    0.0222    0.0089    0.0108    0.0215    0.0136    0.0659
# 96     0.0181    0.0146    0.0026    0.0141    0.0421    0.0473    0.0361
# 166    0.0411    0.0277    0.0604    0.0525    0.0489    0.0385    0.0611
#
#      feature8  feature9  feature10  ...  feature52  feature53  feature54  \
# 161    0.0972    0.2535     0.3127  ...     0.0200     0.0070     0.0070
# 15     0.2033    0.1459     0.0852  ...     0.0031     0.0153     0.0071
# 73     0.0954    0.0786     0.1015  ...     0.0062     0.0072     0.0113
# 96     0.0741    0.1398     0.1045  ...     0.0223     0.0255     0.0145
# 166    0.1117    0.1237     0.2300  ...     0.0217     0.0038     0.0019
#
#      feature55  feature56  feature57  feature58  feature59  feature60  label
# 161     0.0086     0.0089     0.0074     0.0042     0.0055     0.0021      1
# 15      0.0212     0.0076     0.0152     0.0049     0.0200     0.0073      0
# 73      0.0012     0.0022     0.0025     0.0059     0.0039     0.0048      0
# 96      0.0233     0.0041     0.0018     0.0048     0.0089     0.0085      0
# 166     0.0065     0.0132     0.0108     0.0050     0.0085     0.0044      1
#
# [5 rows x 61 columns]

# %%
train_df, test_df = train_test_split(sonar_df, test_size = 0.2, random_state = 12)
X_train = train_df.drop("label", axis = 1)
y_train = train_df["label"]
X_test = test_df.drop("label", axis = 1)
y_test = test_df["label"]

# %%
results_knn, scaler = classifier_selecting.optimize_classifier(X_train, X_test, y_train, y_test, 'knn')

print("\nBest Parameters:", results_knn['best_parameters'])
print("\nBest Cross-validation Score:", results_knn['best_score'])
print("\nFeature Importances:", results_knn['feature_importances'])
print("\nClassification Report:")
print(classification_report(y_test, results_knn['best_model'].predict(
    scaler.fit_transform(X_test))))
# Out:
# n_jobs = -1
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
#
# Best Parameters: {'algorithm': 'auto', 'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
#
# Best Cross-validation Score: 0.8515609560085888
#
# Feature Importances: None
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.84      0.89        19
#            1       0.88      0.96      0.92        23
#
#     accuracy                           0.90        42
#    macro avg       0.91      0.90      0.90        42
# weighted avg       0.91      0.90      0.90        42

# %%
knn = KNeighborsClassifier(**results_knn['best_parameters'])

sbs_knn = SequentialBackwardSelection(estimator=knn,
                                      min_features = 3,
                                      scoring_metric=accuracy_score,
                                      scale_features=True,
                                      verbose=True)
sbs_knn.fit(X_train, X_test, y_train, y_test)
# Out:
# Removed feature: feature27
# Current performance: 0.92857
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature2
# Current performance: 0.92857
# Remaining features: ['feature1', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature4
# Current performance: 0.92857
# Remaining features: ['feature1', 'feature3', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature12
# Current performance: 0.92857
# Remaining features: ['feature1', 'feature3', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature14
# Current performance: 0.92857
# Remaining features: ['feature1', 'feature3', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature1
# Current performance: 0.92857
# Remaining features: ['feature3', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature6
# Current performance: 0.92857
# Remaining features: ['feature3', 'feature5', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature7
# Current performance: 0.92857
# Remaining features: ['feature3', 'feature5', 'feature8', 'feature9', 'feature10', 'feature11', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature15
# Current performance: 0.95238
# Remaining features: ['feature3', 'feature5', 'feature8', 'feature9', 'feature10', 'feature11', 'feature13', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature5
# Current performance: 0.95238
# Remaining features: ['feature3', 'feature8', 'feature9', 'feature10', 'feature11', 'feature13', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature11
# Current performance: 0.95238
# Remaining features: ['feature3', 'feature8', 'feature9', 'feature10', 'feature13', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature17
# Current performance: 0.97619
# Remaining features: ['feature3', 'feature8', 'feature9', 'feature10', 'feature13', 'feature16', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature19
# Current performance: 0.97619
# Remaining features: ['feature3', 'feature8', 'feature9', 'feature10', 'feature13', 'feature16', 'feature18', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature3
# Current performance: 0.97619
# Remaining features: ['feature8', 'feature9', 'feature10', 'feature13', 'feature16', 'feature18', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature8
# Current performance: 0.97619
# Remaining features: ['feature9', 'feature10', 'feature13', 'feature16', 'feature18', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature16
# Current performance: 0.97619
# Remaining features: ['feature9', 'feature10', 'feature13', 'feature18', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature20
# Current performance: 0.97619
# Remaining features: ['feature9', 'feature10', 'feature13', 'feature18', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature13
# Current performance: 0.97619
# Remaining features: ['feature9', 'feature10', 'feature18', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature21
# Current performance: 0.97619
# Remaining features: ['feature9', 'feature10', 'feature18', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature29
# Current performance: 0.97619
# Remaining features: ['feature9', 'feature10', 'feature18', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature18
# Current performance: 0.97619
# Remaining features: ['feature9', 'feature10', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature33
# Current performance: 0.97619
# Remaining features: ['feature9', 'feature10', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature25
# Current performance: 0.97619
# Remaining features: ['feature9', 'feature10', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature34
# Current performance: 0.95238
# Remaining features: ['feature9', 'feature10', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature30', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature31
# Current performance: 0.95238
# Remaining features: ['feature9', 'feature10', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature30', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature59
# Current performance: 0.97619
# Remaining features: ['feature9', 'feature10', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature30', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature45
# Current performance: 0.97619
# Remaining features: ['feature9', 'feature10', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature30', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature47
# Current performance: 0.97619
# Remaining features: ['feature9', 'feature10', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature30', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature46', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature9
# Current performance: 0.95238
# Remaining features: ['feature10', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature30', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature46', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature44
# Current performance: 0.95238
# Remaining features: ['feature10', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature30', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature46', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature48
# Current performance: 0.95238
# Remaining features: ['feature10', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature30', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature46', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature41
# Current performance: 0.95238
# Remaining features: ['feature10', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature30', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature46', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature26
# Current performance: 0.92857
# Remaining features: ['feature10', 'feature22', 'feature23', 'feature24', 'feature28', 'feature30', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature46', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature35
# Current performance: 0.95238
# Remaining features: ['feature10', 'feature22', 'feature23', 'feature24', 'feature28', 'feature30', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature46', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature49
# Current performance: 0.95238
# Remaining features: ['feature10', 'feature22', 'feature23', 'feature24', 'feature28', 'feature30', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature46', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature42
# Current performance: 0.95238
# Remaining features: ['feature10', 'feature22', 'feature23', 'feature24', 'feature28', 'feature30', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature43', 'feature46', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature24
# Current performance: 0.92857
# Remaining features: ['feature10', 'feature22', 'feature23', 'feature28', 'feature30', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature43', 'feature46', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature30
# Current performance: 0.95238
# Remaining features: ['feature10', 'feature22', 'feature23', 'feature28', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature43', 'feature46', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature55
# Current performance: 0.92857
# Remaining features: ['feature10', 'feature22', 'feature23', 'feature28', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature43', 'feature46', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature23
# Current performance: 0.92857
# Remaining features: ['feature10', 'feature22', 'feature28', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature43', 'feature46', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature53
# Current performance: 0.95238
# Remaining features: ['feature10', 'feature22', 'feature28', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature43', 'feature46', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature28
# Current performance: 0.92857
# Remaining features: ['feature10', 'feature22', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature43', 'feature46', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature10
# Current performance: 0.90476
# Remaining features: ['feature22', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature43', 'feature46', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature50
# Current performance: 0.92857
# Remaining features: ['feature22', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature43', 'feature46', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature40
# Current performance: 0.95238
# Remaining features: ['feature22', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature43', 'feature46', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature58
# Current performance: 0.95238
# Remaining features: ['feature22', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature43', 'feature46', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature60']
#
#
# Removed feature: feature52
# Current performance: 0.92857
# Remaining features: ['feature22', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature43', 'feature46', 'feature51', 'feature54', 'feature56', 'feature57', 'feature60']
#
#
# Removed feature: feature56
# Current performance: 0.92857
# Remaining features: ['feature22', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature43', 'feature46', 'feature51', 'feature54', 'feature57', 'feature60']
#
#
# Removed feature: feature37
# Current performance: 0.92857
# Remaining features: ['feature22', 'feature32', 'feature36', 'feature38', 'feature39', 'feature43', 'feature46', 'feature51', 'feature54', 'feature57', 'feature60']
#
#
# Removed feature: feature32
# Current performance: 0.90476
# Remaining features: ['feature22', 'feature36', 'feature38', 'feature39', 'feature43', 'feature46', 'feature51', 'feature54', 'feature57', 'feature60']
#
#
# Removed feature: feature57
# Current performance: 0.90476
# Remaining features: ['feature22', 'feature36', 'feature38', 'feature39', 'feature43', 'feature46', 'feature51', 'feature54', 'feature60']
#
#
# Removed feature: feature22
# Current performance: 0.88095
# Remaining features: ['feature36', 'feature38', 'feature39', 'feature43', 'feature46', 'feature51', 'feature54', 'feature60']
#
#
# Removed feature: feature54
# Current performance: 0.90476
# Remaining features: ['feature36', 'feature38', 'feature39', 'feature43', 'feature46', 'feature51', 'feature60']
#
#
# Removed feature: feature60
# Current performance: 0.85714
# Remaining features: ['feature36', 'feature38', 'feature39', 'feature43', 'feature46', 'feature51']
#
#
# Removed feature: feature38
# Current performance: 0.83333
# Remaining features: ['feature36', 'feature39', 'feature43', 'feature46', 'feature51']
#
#
# Removed feature: feature51
# Current performance: 0.80952
# Remaining features: ['feature36', 'feature39', 'feature43', 'feature46']
#
#
# Removed feature: feature46
# Current performance: 0.78571
# Remaining features: ['feature36', 'feature39', 'feature43']

# %%
results_perceptron, scaler = classifier_selecting.optimize_classifier(X_train, X_test, y_train, y_test, 'perceptron')

print("\nBest Parameters:", results_perceptron['best_parameters'])
print("\nBest Cross-validation Score:", results_perceptron['best_score'])
print("\nFeature Importances:", results_perceptron['feature_importances'])
print("\nClassification Report:")
print(classification_report(y_test, results_perceptron['best_model'].predict(
    scaler.fit_transform(X_test))))
# Out:
# Warning: Large parameter grid for perceptron. Switching to RandomizedSearchCV
# n_jobs = -1
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# /home/soulangel443/.local/share/mise/installs/python/latest/lib/python3.12/site-packages/sklearn/model_selection/_search.py:317: UserWarning: The total space of parameters 48 is smaller than n_iter=100. Running 48 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best Parameters: {'validation_fraction': 0.1, 'tol': 0.001, 'penalty': 'l1', 'max_iter': 500, 'early_stopping': True, 'alpha': 0.0001}
#
# Best Cross-validation Score: 0.8143680121099477
#
# Feature Importances: {'feature1': 11.07352501689784, 'feature2': 0.17169724352320614, 'feature3': 9.869132638056485, 'feature4': 4.270026806238162, 'feature5': 5.098106973024596, 'feature6': 2.7007461745992773, 'feature7': 4.552819380503664, 'feature8': 10.449916377503849, 'feature9': 13.360286625255304, 'feature10': 2.9458780911280176, 'feature11': 5.097132623602901, 'feature12': 7.575539137189044, 'feature13': 7.297143267044234, 'feature14': 3.1355964974433683, 'feature15': 0.27995613884069065, 'feature16': 1.23341602331711, 'feature17': 7.888925103579505, 'feature18': 6.057266866629248, 'feature19': 8.219509336165551, 'feature20': 6.3877104320293965, 'feature21': 5.932915765085336, 'feature22': 4.105625430472312, 'feature23': 3.857071378086321, 'feature24': 5.343735252810833, 'feature25': 3.616588545484087, 'feature26': 2.2330801617936786, 'feature27': 0.6258624680191827, 'feature28': 1.3576544411417175, 'feature29': 4.296181547730832, 'feature30': 8.465426630069828, 'feature31': 11.822563718422979, 'feature32': 3.9798682620986914, 'feature33': 3.1073514392175734, 'feature34': 1.0209730444627976, 'feature35': 0.8526622853568199, 'feature36': 10.781624900844651, 'feature37': 14.690595714962923, 'feature38': 4.71722419855673, 'feature39': 5.343772584597846, 'feature40': 16.701440121583143, 'feature41': 0.6581400691922715, 'feature42': 3.8603039776512995, 'feature43': 3.472516572948821, 'feature44': 8.240411139608605, 'feature45': 10.753811532082135, 'feature46': 6.766194231152203, 'feature47': 0.22394332189642757, 'feature48': 8.323061668902595, 'feature49': 7.105020362724118, 'feature50': 19.3872069635147, 'feature51': 2.3457762223523377, 'feature52': 15.316738457321923, 'feature53': 0.8463657189155196, 'feature54': 2.442550441229554, 'feature55': 1.7415177527498118, 'feature56': 0.20182792875808472, 'feature57': 4.603776362189357, 'feature58': 5.297145818651465, 'feature59': 6.9999752429935835, 'feature60': 4.640514468940317}
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84        19
#            1       0.87      0.87      0.87        23
#
#     accuracy                           0.86        42
#    macro avg       0.86      0.86      0.86        42
# weighted avg       0.86      0.86      0.86        42

# %%
perceptron = Perceptron(**results_perceptron['best_parameters'])

sbs_perceptron = SequentialBackwardSelection(estimator=perceptron,
                                             min_features = 3,
                                             scoring_metric=accuracy_score,
                                             scale_features=True,
                                             verbose=True)
sbs_perceptron.fit(X_train, X_test, y_train, y_test)
# Out:
# Removed feature: feature5
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature41
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature22
# Current performance: 0.85714
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature17
# Current performance: 0.92857
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature18', 'feature19', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature33
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature18', 'feature19', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature16
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature19', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature34
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature19', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature18
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature19', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature14
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature15', 'feature19', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature19
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature15', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature28
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature15', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature29', 'feature30', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature30
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature15', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature25
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature15', 'feature20', 'feature21', 'feature23', 'feature24', 'feature26', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature23
# Current performance: 0.85714
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature15', 'feature20', 'feature21', 'feature24', 'feature26', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature13
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature15', 'feature20', 'feature21', 'feature24', 'feature26', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature3
# Current performance: 0.95238
# Remaining features: ['feature1', 'feature2', 'feature4', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature15', 'feature20', 'feature21', 'feature24', 'feature26', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature6
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature2', 'feature4', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature15', 'feature20', 'feature21', 'feature24', 'feature26', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature26
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature2', 'feature4', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature15', 'feature20', 'feature21', 'feature24', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature2
# Current performance: 0.85714
# Remaining features: ['feature1', 'feature4', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature15', 'feature20', 'feature21', 'feature24', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature21
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature4', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature15', 'feature20', 'feature24', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature46
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature4', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature15', 'feature20', 'feature24', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature38
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature4', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature15', 'feature20', 'feature24', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature57
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature4', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature15', 'feature20', 'feature24', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature50
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature4', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature15', 'feature20', 'feature24', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature58
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature4', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature15', 'feature20', 'feature24', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature59', 'feature60']
#
#
# Removed feature: feature1
# Current performance: 0.88095
# Remaining features: ['feature4', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature15', 'feature20', 'feature24', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature59', 'feature60']
#
#
# Removed feature: feature51
# Current performance: 0.88095
# Remaining features: ['feature4', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature15', 'feature20', 'feature24', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature59', 'feature60']
#
#
# Removed feature: feature12
# Current performance: 0.85714
# Remaining features: ['feature4', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature15', 'feature20', 'feature24', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature59', 'feature60']
#
#
# Removed feature: feature24
# Current performance: 0.85714
# Remaining features: ['feature4', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature15', 'feature20', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature59', 'feature60']
#
#
# Removed feature: feature8
# Current performance: 0.92857
# Remaining features: ['feature4', 'feature7', 'feature9', 'feature10', 'feature11', 'feature15', 'feature20', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature59', 'feature60']
#
#
# Removed feature: feature7
# Current performance: 0.88095
# Remaining features: ['feature4', 'feature9', 'feature10', 'feature11', 'feature15', 'feature20', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature59', 'feature60']
#
#
# Removed feature: feature52
# Current performance: 0.90476
# Remaining features: ['feature4', 'feature9', 'feature10', 'feature11', 'feature15', 'feature20', 'feature27', 'feature29', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature53', 'feature54', 'feature55', 'feature56', 'feature59', 'feature60']
#
#
# Removed feature: feature29
# Current performance: 0.88095
# Remaining features: ['feature4', 'feature9', 'feature10', 'feature11', 'feature15', 'feature20', 'feature27', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature53', 'feature54', 'feature55', 'feature56', 'feature59', 'feature60']
#
#
# Removed feature: feature10
# Current performance: 0.85714
# Remaining features: ['feature4', 'feature9', 'feature11', 'feature15', 'feature20', 'feature27', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature53', 'feature54', 'feature55', 'feature56', 'feature59', 'feature60']
#
#
# Removed feature: feature60
# Current performance: 0.88095
# Remaining features: ['feature4', 'feature9', 'feature11', 'feature15', 'feature20', 'feature27', 'feature31', 'feature32', 'feature35', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature53', 'feature54', 'feature55', 'feature56', 'feature59']
#
#
# Removed feature: feature35
# Current performance: 0.88095
# Remaining features: ['feature4', 'feature9', 'feature11', 'feature15', 'feature20', 'feature27', 'feature31', 'feature32', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature53', 'feature54', 'feature55', 'feature56', 'feature59']
#
#
# Removed feature: feature53
# Current performance: 0.88095
# Remaining features: ['feature4', 'feature9', 'feature11', 'feature15', 'feature20', 'feature27', 'feature31', 'feature32', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature54', 'feature55', 'feature56', 'feature59']
#
#
# Removed feature: feature37
# Current performance: 0.90476
# Remaining features: ['feature4', 'feature9', 'feature11', 'feature15', 'feature20', 'feature27', 'feature31', 'feature32', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature54', 'feature55', 'feature56', 'feature59']
#
#
# Removed feature: feature47
# Current performance: 0.88095
# Remaining features: ['feature4', 'feature9', 'feature11', 'feature15', 'feature20', 'feature27', 'feature31', 'feature32', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature48', 'feature49', 'feature54', 'feature55', 'feature56', 'feature59']
#
#
# Removed feature: feature55
# Current performance: 0.90476
# Remaining features: ['feature4', 'feature9', 'feature11', 'feature15', 'feature20', 'feature27', 'feature31', 'feature32', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature48', 'feature49', 'feature54', 'feature56', 'feature59']
#
#
# Removed feature: feature42
# Current performance: 0.88095
# Remaining features: ['feature4', 'feature9', 'feature11', 'feature15', 'feature20', 'feature27', 'feature31', 'feature32', 'feature36', 'feature39', 'feature40', 'feature43', 'feature44', 'feature45', 'feature48', 'feature49', 'feature54', 'feature56', 'feature59']
#
#
# Removed feature: feature40
# Current performance: 0.85714
# Remaining features: ['feature4', 'feature9', 'feature11', 'feature15', 'feature20', 'feature27', 'feature31', 'feature32', 'feature36', 'feature39', 'feature43', 'feature44', 'feature45', 'feature48', 'feature49', 'feature54', 'feature56', 'feature59']
#
#
# Removed feature: feature11
# Current performance: 0.83333
# Remaining features: ['feature4', 'feature9', 'feature15', 'feature20', 'feature27', 'feature31', 'feature32', 'feature36', 'feature39', 'feature43', 'feature44', 'feature45', 'feature48', 'feature49', 'feature54', 'feature56', 'feature59']
#
#
# Removed feature: feature27
# Current performance: 0.78571
# Remaining features: ['feature4', 'feature9', 'feature15', 'feature20', 'feature31', 'feature32', 'feature36', 'feature39', 'feature43', 'feature44', 'feature45', 'feature48', 'feature49', 'feature54', 'feature56', 'feature59']
#
#
# Removed feature: feature44
# Current performance: 0.83333
# Remaining features: ['feature4', 'feature9', 'feature15', 'feature20', 'feature31', 'feature32', 'feature36', 'feature39', 'feature43', 'feature45', 'feature48', 'feature49', 'feature54', 'feature56', 'feature59']
#
#
# Removed feature: feature49
# Current performance: 0.83333
# Remaining features: ['feature4', 'feature9', 'feature15', 'feature20', 'feature31', 'feature32', 'feature36', 'feature39', 'feature43', 'feature45', 'feature48', 'feature54', 'feature56', 'feature59']
#
#
# Removed feature: feature9
# Current performance: 0.85714
# Remaining features: ['feature4', 'feature15', 'feature20', 'feature31', 'feature32', 'feature36', 'feature39', 'feature43', 'feature45', 'feature48', 'feature54', 'feature56', 'feature59']
#
#
# Removed feature: feature15
# Current performance: 0.85714
# Remaining features: ['feature4', 'feature20', 'feature31', 'feature32', 'feature36', 'feature39', 'feature43', 'feature45', 'feature48', 'feature54', 'feature56', 'feature59']
#
#
# Removed feature: feature32
# Current performance: 0.88095
# Remaining features: ['feature4', 'feature20', 'feature31', 'feature36', 'feature39', 'feature43', 'feature45', 'feature48', 'feature54', 'feature56', 'feature59']
#
#
# Removed feature: feature20
# Current performance: 0.83333
# Remaining features: ['feature4', 'feature31', 'feature36', 'feature39', 'feature43', 'feature45', 'feature48', 'feature54', 'feature56', 'feature59']
#
#
# Removed feature: feature31
# Current performance: 0.7381
# Remaining features: ['feature4', 'feature36', 'feature39', 'feature43', 'feature45', 'feature48', 'feature54', 'feature56', 'feature59']
#
#
# Removed feature: feature39
# Current performance: 0.78571
# Remaining features: ['feature4', 'feature36', 'feature43', 'feature45', 'feature48', 'feature54', 'feature56', 'feature59']
#
#
# Removed feature: feature43
# Current performance: 0.80952
# Remaining features: ['feature4', 'feature36', 'feature45', 'feature48', 'feature54', 'feature56', 'feature59']
#
#
# Removed feature: feature56
# Current performance: 0.69048
# Remaining features: ['feature4', 'feature36', 'feature45', 'feature48', 'feature54', 'feature59']
#
#
# Removed feature: feature45
# Current performance: 0.7619
# Remaining features: ['feature4', 'feature36', 'feature48', 'feature54', 'feature59']
#
#
# Removed feature: feature59
# Current performance: 0.78571
# Remaining features: ['feature4', 'feature36', 'feature48', 'feature54']
#
#
# Removed feature: feature54
# Current performance: 0.61905
# Remaining features: ['feature4', 'feature36', 'feature48']

# %%
results_rf, scaler = classifier_selecting.optimize_classifier(X_train, X_test, y_train, y_test, 'rf')

print("\nBest Parameters:", results_rf['best_parameters'])
print("\nBest Cross-validation Score:", results_rf['best_score'])
print("\nFeature Importances:", results_rf['feature_importances'])
print("\nClassification Report:")
print(classification_report(y_test, results_rf['best_model'].predict(
    scaler.fit_transform(X_test))))
# Out:
# Warning: Large parameter grid for rf. Switching to RandomizedSearchCV
# n_jobs = -1
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'gini', 'class_weight': 'balanced', 'bootstrap': True}
#
# Best Cross-validation Score: 0.8544456163032015
#
# Feature Importances: {'feature1': 0.015677897814338433, 'feature2': 0.010295899145119115, 'feature3': 0.012565556263610507, 'feature4': 0.015415226424666155, 'feature5': 0.01652955489047023, 'feature6': 0.017627676412862288, 'feature7': 0.008274151328006104, 'feature8': 0.012972617095836296, 'feature9': 0.04343114603343299, 'feature10': 0.032143731103825, 'feature11': 0.04800487629312707, 'feature12': 0.04494126165045112, 'feature13': 0.018569634828129573, 'feature14': 0.012017486636093953, 'feature15': 0.013244767619156243, 'feature16': 0.014450428757482911, 'feature17': 0.017952052249520175, 'feature18': 0.011418364578235696, 'feature19': 0.008575936228592639, 'feature20': 0.013395992069402863, 'feature21': 0.011714453874764398, 'feature22': 0.009346112873180275, 'feature23': 0.015374768196662466, 'feature24': 0.012835953764567956, 'feature25': 0.013400926096572655, 'feature26': 0.011547386117849232, 'feature27': 0.021614424914215065, 'feature28': 0.024093240817527034, 'feature29': 0.012483385022341056, 'feature30': 0.010944044403869946, 'feature31': 0.012412533072836626, 'feature32': 0.010775430619173465, 'feature33': 0.01095847848080693, 'feature34': 0.011857209710364667, 'feature35': 0.018905276147964428, 'feature36': 0.028334801824410758, 'feature37': 0.019429833606035497, 'feature38': 0.00785502405718702, 'feature39': 0.010225520139685612, 'feature40': 0.010071564465778999, 'feature41': 0.009005569993493898, 'feature42': 0.011726397279331441, 'feature43': 0.01985870614197115, 'feature44': 0.022025720199613803, 'feature45': 0.01881291862321898, 'feature46': 0.027440590640683233, 'feature47': 0.02534071332847843, 'feature48': 0.03159116922190069, 'feature49': 0.033893136279537654, 'feature50': 0.012660008077180608, 'feature51': 0.019198484948662952, 'feature52': 0.019318074606155453, 'feature53': 0.009189592330134404, 'feature54': 0.014218173834398643, 'feature55': 0.009296720051007706, 'feature56': 0.0074768590696201315, 'feature57': 0.010778923279390557, 'feature58': 0.009983124312734078, 'feature59': 0.008089698012559206, 'feature60': 0.0084107941417737}
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84        19
#            1       0.87      0.87      0.87        23
#
#     accuracy                           0.86        42
#    macro avg       0.86      0.86      0.86        42
# weighted avg       0.86      0.86      0.86        42

# %%
rf = RandomForestClassifier(**results_rf['best_parameters'])

sbs_rf = SequentialBackwardSelection(estimator=rf,
                                     min_features = 3,
                                     scoring_metric=accuracy_score,
                                     scale_features=True,
                                     verbose=True)
sbs_rf.fit(X_train, X_test, y_train, y_test)
# Out:
# Removed feature: feature9
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature46
# Current performance: 0.95238
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature45
# Current performance: 0.92857
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature25
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature18
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature11
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature10', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature2
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature10', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature55
# Current performance: 0.92857
# Remaining features: ['feature1', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature10', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature1
# Current performance: 0.90476
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature10', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature17
# Current performance: 0.90476
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature10', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature6
# Current performance: 0.90476
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature7', 'feature8', 'feature10', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature59
# Current performance: 0.92857
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature7', 'feature8', 'feature10', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature27
# Current performance: 0.90476
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature7', 'feature8', 'feature10', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature16
# Current performance: 0.92857
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature7', 'feature8', 'feature10', 'feature12', 'feature13', 'feature14', 'feature15', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature13
# Current performance: 0.90476
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature7', 'feature8', 'feature10', 'feature12', 'feature14', 'feature15', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature36
# Current performance: 0.90476
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature7', 'feature8', 'feature10', 'feature12', 'feature14', 'feature15', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature33
# Current performance: 0.90476
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature7', 'feature8', 'feature10', 'feature12', 'feature14', 'feature15', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature15
# Current performance: 0.90476
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature7', 'feature8', 'feature10', 'feature12', 'feature14', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature7
# Current performance: 0.88095
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature8', 'feature10', 'feature12', 'feature14', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature48
# Current performance: 0.90476
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature8', 'feature10', 'feature12', 'feature14', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature24
# Current performance: 0.92857
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature8', 'feature10', 'feature12', 'feature14', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature49
# Current performance: 0.92857
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature8', 'feature10', 'feature12', 'feature14', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature42
# Current performance: 0.95238
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature8', 'feature10', 'feature12', 'feature14', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature53
# Current performance: 0.92857
# Remaining features: ['feature3', 'feature4', 'feature5', 'feature8', 'feature10', 'feature12', 'feature14', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature4
# Current performance: 0.90476
# Remaining features: ['feature3', 'feature5', 'feature8', 'feature10', 'feature12', 'feature14', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature35
# Current performance: 0.90476
# Remaining features: ['feature3', 'feature5', 'feature8', 'feature10', 'feature12', 'feature14', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature10
# Current performance: 0.90476
# Remaining features: ['feature3', 'feature5', 'feature8', 'feature12', 'feature14', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature26', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature29
# Current performance: 0.92857
# Remaining features: ['feature3', 'feature5', 'feature8', 'feature12', 'feature14', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature26', 'feature28', 'feature30', 'feature31', 'feature32', 'feature34', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature39
# Current performance: 0.95238
# Remaining features: ['feature3', 'feature5', 'feature8', 'feature12', 'feature14', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature26', 'feature28', 'feature30', 'feature31', 'feature32', 'feature34', 'feature37', 'feature38', 'feature40', 'feature41', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature47
# Current performance: 0.97619
# Remaining features: ['feature3', 'feature5', 'feature8', 'feature12', 'feature14', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature26', 'feature28', 'feature30', 'feature31', 'feature32', 'feature34', 'feature37', 'feature38', 'feature40', 'feature41', 'feature43', 'feature44', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature5
# Current performance: 0.92857
# Remaining features: ['feature3', 'feature8', 'feature12', 'feature14', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature26', 'feature28', 'feature30', 'feature31', 'feature32', 'feature34', 'feature37', 'feature38', 'feature40', 'feature41', 'feature43', 'feature44', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature34
# Current performance: 0.95238
# Remaining features: ['feature3', 'feature8', 'feature12', 'feature14', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature26', 'feature28', 'feature30', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature43', 'feature44', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature20
# Current performance: 0.97619
# Remaining features: ['feature3', 'feature8', 'feature12', 'feature14', 'feature19', 'feature21', 'feature22', 'feature23', 'feature26', 'feature28', 'feature30', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature43', 'feature44', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature30
# Current performance: 0.97619
# Remaining features: ['feature3', 'feature8', 'feature12', 'feature14', 'feature19', 'feature21', 'feature22', 'feature23', 'feature26', 'feature28', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature43', 'feature44', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature19
# Current performance: 0.97619
# Remaining features: ['feature3', 'feature8', 'feature12', 'feature14', 'feature21', 'feature22', 'feature23', 'feature26', 'feature28', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature43', 'feature44', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature26
# Current performance: 0.95238
# Remaining features: ['feature3', 'feature8', 'feature12', 'feature14', 'feature21', 'feature22', 'feature23', 'feature28', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature43', 'feature44', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature57', 'feature58', 'feature60']
#
#
# Removed feature: feature57
# Current performance: 0.97619
# Remaining features: ['feature3', 'feature8', 'feature12', 'feature14', 'feature21', 'feature22', 'feature23', 'feature28', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature43', 'feature44', 'feature50', 'feature51', 'feature52', 'feature54', 'feature56', 'feature58', 'feature60']
#
#
# Removed feature: feature50
# Current performance: 0.97619
# Remaining features: ['feature3', 'feature8', 'feature12', 'feature14', 'feature21', 'feature22', 'feature23', 'feature28', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature43', 'feature44', 'feature51', 'feature52', 'feature54', 'feature56', 'feature58', 'feature60']
#
#
# Removed feature: feature3
# Current performance: 0.97619
# Remaining features: ['feature8', 'feature12', 'feature14', 'feature21', 'feature22', 'feature23', 'feature28', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature43', 'feature44', 'feature51', 'feature52', 'feature54', 'feature56', 'feature58', 'feature60']
#
#
# Removed feature: feature8
# Current performance: 0.95238
# Remaining features: ['feature12', 'feature14', 'feature21', 'feature22', 'feature23', 'feature28', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature43', 'feature44', 'feature51', 'feature52', 'feature54', 'feature56', 'feature58', 'feature60']
#
#
# Removed feature: feature60
# Current performance: 0.97619
# Remaining features: ['feature12', 'feature14', 'feature21', 'feature22', 'feature23', 'feature28', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature43', 'feature44', 'feature51', 'feature52', 'feature54', 'feature56', 'feature58']
#
#
# Removed feature: feature21
# Current performance: 0.95238
# Remaining features: ['feature12', 'feature14', 'feature22', 'feature23', 'feature28', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature43', 'feature44', 'feature51', 'feature52', 'feature54', 'feature56', 'feature58']
#
#
# Removed feature: feature23
# Current performance: 0.90476
# Remaining features: ['feature12', 'feature14', 'feature22', 'feature28', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature43', 'feature44', 'feature51', 'feature52', 'feature54', 'feature56', 'feature58']
#
#
# Removed feature: feature43
# Current performance: 0.88095
# Remaining features: ['feature12', 'feature14', 'feature22', 'feature28', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature44', 'feature51', 'feature52', 'feature54', 'feature56', 'feature58']
#
#
# Removed feature: feature51
# Current performance: 0.90476
# Remaining features: ['feature12', 'feature14', 'feature22', 'feature28', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature44', 'feature52', 'feature54', 'feature56', 'feature58']
#
#
# Removed feature: feature52
# Current performance: 0.90476
# Remaining features: ['feature12', 'feature14', 'feature22', 'feature28', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature44', 'feature54', 'feature56', 'feature58']
#
#
# Removed feature: feature22
# Current performance: 0.88095
# Remaining features: ['feature12', 'feature14', 'feature28', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature44', 'feature54', 'feature56', 'feature58']
#
#
# Removed feature: feature28
# Current performance: 0.90476
# Remaining features: ['feature12', 'feature14', 'feature31', 'feature32', 'feature37', 'feature38', 'feature40', 'feature41', 'feature44', 'feature54', 'feature56', 'feature58']
#
#
# Removed feature: feature32
# Current performance: 0.92857
# Remaining features: ['feature12', 'feature14', 'feature31', 'feature37', 'feature38', 'feature40', 'feature41', 'feature44', 'feature54', 'feature56', 'feature58']
#
#
# Removed feature: feature40
# Current performance: 0.90476
# Remaining features: ['feature12', 'feature14', 'feature31', 'feature37', 'feature38', 'feature41', 'feature44', 'feature54', 'feature56', 'feature58']
#
#
# Removed feature: feature44
# Current performance: 0.90476
# Remaining features: ['feature12', 'feature14', 'feature31', 'feature37', 'feature38', 'feature41', 'feature54', 'feature56', 'feature58']
#
#
# Removed feature: feature38
# Current performance: 0.92857
# Remaining features: ['feature12', 'feature14', 'feature31', 'feature37', 'feature41', 'feature54', 'feature56', 'feature58']
#
#
# Removed feature: feature56
# Current performance: 0.92857
# Remaining features: ['feature12', 'feature14', 'feature31', 'feature37', 'feature41', 'feature54', 'feature58']
#
#
# Removed feature: feature31
# Current performance: 0.90476
# Remaining features: ['feature12', 'feature14', 'feature37', 'feature41', 'feature54', 'feature58']
#
#
# Removed feature: feature58
# Current performance: 0.90476
# Remaining features: ['feature12', 'feature14', 'feature37', 'feature41', 'feature54']
#
#
# Removed feature: feature41
# Current performance: 0.85714
# Remaining features: ['feature12', 'feature14', 'feature37', 'feature54']
#
#
# Removed feature: feature37
# Current performance: 0.80952
# Remaining features: ['feature12', 'feature14', 'feature54']

# %%
results_dt, scaler = classifier_selecting.optimize_classifier(X_train, X_test, y_train, y_test, 'dt')

print("\nBest Parameters:", results_dt['best_parameters'])
print("\nBest Cross-validation Score:", results_dt['best_score'])
print("\nFeature Importances:", results_dt['feature_importances'])
print("\nClassification Report:")
print(classification_report(y_test, results_dt['best_model'].predict(
    scaler.fit_transform(X_test))))
# Out:
# Warning: Large parameter grid for dt. Switching to RandomizedSearchCV
# n_jobs = -1
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#
# Best Parameters: {'splitter': 'random', 'min_samples_split': 20, 'min_samples_leaf': 8, 'min_impurity_decrease': 0.0, 'max_features': None, 'max_depth': 40, 'criterion': 'gini', 'class_weight': None}
#
# Best Cross-validation Score: 0.8008102258102259
#
# Feature Importances: {'feature1': 0.0, 'feature2': 0.0, 'feature3': 0.0, 'feature4': 0.0, 'feature5': 0.0, 'feature6': 0.0, 'feature7': 0.0, 'feature8': 0.0, 'feature9': 0.0, 'feature10': 0.0, 'feature11': 0.0, 'feature12': 0.3018182990710312, 'feature13': 0.0640494328181202, 'feature14': 0.0, 'feature15': 0.0, 'feature16': 0.0, 'feature17': 0.12111776885949921, 'feature18': 0.057887980322151436, 'feature19': 0.0, 'feature20': 0.0, 'feature21': 0.0, 'feature22': 0.0, 'feature23': 0.0, 'feature24': 0.0, 'feature25': 0.0, 'feature26': 0.0, 'feature27': 0.19615304214468407, 'feature28': 0.0, 'feature29': 0.0, 'feature30': 0.0, 'feature31': 0.07266392454825339, 'feature32': 0.0, 'feature33': 0.0, 'feature34': 0.0, 'feature35': 0.0, 'feature36': 0.0, 'feature37': 0.0036545342487342308, 'feature38': 0.0, 'feature39': 0.0, 'feature40': 0.0, 'feature41': 0.0, 'feature42': 0.0, 'feature43': 0.0, 'feature44': 0.0, 'feature45': 0.0, 'feature46': 0.0, 'feature47': 0.0, 'feature48': 0.06664763259020831, 'feature49': 0.0, 'feature50': 0.0, 'feature51': 0.0, 'feature52': 0.0, 'feature53': 0.0, 'feature54': 0.08567748664977999, 'feature55': 0.0, 'feature56': 0.0, 'feature57': 0.0, 'feature58': 0.030329898747537946, 'feature59': 0.0, 'feature60': 0.0}
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.79      0.71        19
#            1       0.79      0.65      0.71        23
#
#     accuracy                           0.71        42
#    macro avg       0.72      0.72      0.71        42
# weighted avg       0.73      0.71      0.71        42

# %%
dt = DecisionTreeClassifier(**results_dt['best_parameters'])

sbs_dt = SequentialBackwardSelection(estimator=dt,
                                     min_features = 3,
                                     scoring_metric=accuracy_score,
                                     scale_features=True,
                                     verbose=True)
sbs_dt.fit(X_train, X_test, y_train, y_test)
# Out:
# Removed feature: feature41
# Current performance: 0.85714
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature17
# Current performance: 0.83333
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature16
# Current performance: 0.83333
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature7
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature29
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature30
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature19
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature55
# Current performance: 0.85714
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature5
# Current performance: 0.85714
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature46
# Current performance: 0.90476
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature20', 'feature21', 'feature22', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature22
# Current performance: 0.83333
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature1
# Current performance: 0.83333
# Remaining features: ['feature2', 'feature3', 'feature4', 'feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature48
# Current performance: 0.88095
# Remaining features: ['feature2', 'feature3', 'feature4', 'feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature33
# Current performance: 0.85714
# Remaining features: ['feature2', 'feature3', 'feature4', 'feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature10
# Current performance: 0.85714
# Remaining features: ['feature2', 'feature3', 'feature4', 'feature6', 'feature8', 'feature9', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature35
# Current performance: 0.85714
# Remaining features: ['feature2', 'feature3', 'feature4', 'feature6', 'feature8', 'feature9', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature18', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature14
# Current performance: 0.83333
# Remaining features: ['feature2', 'feature3', 'feature4', 'feature6', 'feature8', 'feature9', 'feature11', 'feature12', 'feature13', 'feature15', 'feature18', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature4
# Current performance: 0.83333
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature8', 'feature9', 'feature11', 'feature12', 'feature13', 'feature15', 'feature18', 'feature20', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature20
# Current performance: 0.90476
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature8', 'feature9', 'feature11', 'feature12', 'feature13', 'feature15', 'feature18', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature57
# Current performance: 0.85714
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature8', 'feature9', 'feature11', 'feature12', 'feature13', 'feature15', 'feature18', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature12
# Current performance: 0.85714
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature8', 'feature9', 'feature11', 'feature13', 'feature15', 'feature18', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature56', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature56
# Current performance: 0.83333
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature8', 'feature9', 'feature11', 'feature13', 'feature15', 'feature18', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature38
# Current performance: 0.88095
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature8', 'feature9', 'feature11', 'feature13', 'feature15', 'feature18', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature15
# Current performance: 0.88095
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature8', 'feature9', 'feature11', 'feature13', 'feature18', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature37
# Current performance: 0.85714
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature8', 'feature9', 'feature11', 'feature13', 'feature18', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature34', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature54
# Current performance: 0.83333
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature8', 'feature9', 'feature11', 'feature13', 'feature18', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature34', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature9
# Current performance: 0.83333
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature8', 'feature11', 'feature13', 'feature18', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature34', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature8
# Current performance: 0.78571
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature11', 'feature13', 'feature18', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature27', 'feature28', 'feature31', 'feature32', 'feature34', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature27
# Current performance: 0.83333
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature11', 'feature13', 'feature18', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature31', 'feature32', 'feature34', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature45', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature45
# Current performance: 0.85714
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature11', 'feature13', 'feature18', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature31', 'feature32', 'feature34', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature32
# Current performance: 0.80952
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature11', 'feature13', 'feature18', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature28', 'feature31', 'feature34', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature28
# Current performance: 0.80952
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature11', 'feature13', 'feature18', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature31', 'feature34', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature18
# Current performance: 0.83333
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature11', 'feature13', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature31', 'feature34', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature31
# Current performance: 0.83333
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature11', 'feature13', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature34', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature47', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature49
# Current performance: 0.85714
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature11', 'feature13', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature34', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature34
# Current performance: 0.80952
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature11', 'feature13', 'feature21', 'feature23', 'feature24', 'feature25', 'feature26', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature26
# Current performance: 0.88095
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature11', 'feature13', 'feature21', 'feature23', 'feature24', 'feature25', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature13
# Current performance: 0.85714
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature11', 'feature21', 'feature23', 'feature24', 'feature25', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature60
# Current performance: 0.83333
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature11', 'feature21', 'feature23', 'feature24', 'feature25', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59']
#
#
# Removed feature: feature24
# Current performance: 0.85714
# Remaining features: ['feature2', 'feature3', 'feature6', 'feature11', 'feature21', 'feature23', 'feature25', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59']
#
#
# Removed feature: feature3
# Current performance: 0.83333
# Remaining features: ['feature2', 'feature6', 'feature11', 'feature21', 'feature23', 'feature25', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59']
#
#
# Removed feature: feature23
# Current performance: 0.85714
# Remaining features: ['feature2', 'feature6', 'feature11', 'feature21', 'feature25', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature52', 'feature53', 'feature58', 'feature59']
#
#
# Removed feature: feature52
# Current performance: 0.83333
# Remaining features: ['feature2', 'feature6', 'feature11', 'feature21', 'feature25', 'feature36', 'feature39', 'feature40', 'feature42', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature53', 'feature58', 'feature59']
#
#
# Removed feature: feature40
# Current performance: 0.83333
# Remaining features: ['feature2', 'feature6', 'feature11', 'feature21', 'feature25', 'feature36', 'feature39', 'feature42', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature53', 'feature58', 'feature59']
#
#
# Removed feature: feature6
# Current performance: 0.85714
# Remaining features: ['feature2', 'feature11', 'feature21', 'feature25', 'feature36', 'feature39', 'feature42', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature53', 'feature58', 'feature59']
#
#
# Removed feature: feature2
# Current performance: 0.80952
# Remaining features: ['feature11', 'feature21', 'feature25', 'feature36', 'feature39', 'feature42', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature53', 'feature58', 'feature59']
#
#
# Removed feature: feature42
# Current performance: 0.78571
# Remaining features: ['feature11', 'feature21', 'feature25', 'feature36', 'feature39', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature53', 'feature58', 'feature59']
#
#
# Removed feature: feature53
# Current performance: 0.92857
# Remaining features: ['feature11', 'feature21', 'feature25', 'feature36', 'feature39', 'feature43', 'feature44', 'feature47', 'feature50', 'feature51', 'feature58', 'feature59']
#
#
# Removed feature: feature43
# Current performance: 0.85714
# Remaining features: ['feature11', 'feature21', 'feature25', 'feature36', 'feature39', 'feature44', 'feature47', 'feature50', 'feature51', 'feature58', 'feature59']
#
#
# Removed feature: feature25
# Current performance: 0.80952
# Remaining features: ['feature11', 'feature21', 'feature36', 'feature39', 'feature44', 'feature47', 'feature50', 'feature51', 'feature58', 'feature59']
#
#
# Removed feature: feature51
# Current performance: 0.83333
# Remaining features: ['feature11', 'feature21', 'feature36', 'feature39', 'feature44', 'feature47', 'feature50', 'feature58', 'feature59']
#
#
# Removed feature: feature58
# Current performance: 0.83333
# Remaining features: ['feature11', 'feature21', 'feature36', 'feature39', 'feature44', 'feature47', 'feature50', 'feature59']
#
#
# Removed feature: feature36
# Current performance: 0.88095
# Remaining features: ['feature11', 'feature21', 'feature39', 'feature44', 'feature47', 'feature50', 'feature59']
#
#
# Removed feature: feature21
# Current performance: 0.7619
# Remaining features: ['feature11', 'feature39', 'feature44', 'feature47', 'feature50', 'feature59']
#
#
# Removed feature: feature39
# Current performance: 0.71429
# Remaining features: ['feature11', 'feature44', 'feature47', 'feature50', 'feature59']
#
#
# Removed feature: feature47
# Current performance: 0.80952
# Remaining features: ['feature11', 'feature44', 'feature50', 'feature59']
#
#
# Removed feature: feature44
# Current performance: 0.80952
# Remaining features: ['feature11', 'feature50', 'feature59']

# %%
results_svm, scaler = classifier_selecting.optimize_classifier(X_train, X_test, y_train, y_test, 'svm')

print("\nBest Parameters:", results_svm['best_parameters'])
print("\nBest Cross-validation Score:", results_svm['best_score'])
print("\nFeature Importances:", results_svm['feature_importances'])
print("\nClassification Report:")
print(classification_report(y_test, results_svm['best_model'].predict(
    scaler.fit_transform(X_test))))
# Out:
# Warning: Large parameter grid for svm. Switching to RandomizedSearchCV
# n_jobs = -1
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
#
# Best Parameters: {'kernel': 'rbf', 'gamma': 0.01, 'degree': 2, 'coef0': 0.0, 'class_weight': None, 'C': 10}
#
# Best Cross-validation Score: 0.8922309475869847
#
# Feature Importances: None
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.89      0.79        19
#            1       0.89      0.70      0.78        23
#
#     accuracy                           0.79        42
#    macro avg       0.80      0.80      0.79        42
# weighted avg       0.81      0.79      0.79        42

# %%
svm = SVC(**results_svm['best_parameters'])

sbs_svm = SequentialBackwardSelection(estimator=svm,
                                      min_features = 3,
                                      scoring_metric=accuracy_score,
                                      scale_features=True,
                                      verbose=True)
sbs_svm.fit(X_train, X_test, y_train, y_test)
# Out:
# Removed feature: feature24
# Current performance: 0.83333
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature4
# Current performance: 0.83333
# Remaining features: ['feature1', 'feature2', 'feature3', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature3
# Current performance: 0.85714
# Remaining features: ['feature1', 'feature2', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature2
# Current performance: 0.85714
# Remaining features: ['feature1', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature51', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature51
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature12', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature12
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature5', 'feature6', 'feature7', 'feature8', 'feature9', 'feature10', 'feature11', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature7
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature5', 'feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature13', 'feature14', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature14
# Current performance: 0.88095
# Remaining features: ['feature1', 'feature5', 'feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature1
# Current performance: 0.88095
# Remaining features: ['feature5', 'feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature5
# Current performance: 0.90476
# Remaining features: ['feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature21', 'feature22', 'feature23', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature21
# Current performance: 0.90476
# Remaining features: ['feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature22', 'feature23', 'feature25', 'feature26', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature26
# Current performance: 0.90476
# Remaining features: ['feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature22', 'feature23', 'feature25', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature33', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature33
# Current performance: 0.90476
# Remaining features: ['feature6', 'feature8', 'feature9', 'feature10', 'feature11', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature22', 'feature23', 'feature25', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature11
# Current performance: 0.90476
# Remaining features: ['feature6', 'feature8', 'feature9', 'feature10', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature22', 'feature23', 'feature25', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature56', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature56
# Current performance: 0.92857
# Remaining features: ['feature6', 'feature8', 'feature9', 'feature10', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature22', 'feature23', 'feature25', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature35', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature35
# Current performance: 0.92857
# Remaining features: ['feature6', 'feature8', 'feature9', 'feature10', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature22', 'feature23', 'feature25', 'feature27', 'feature28', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature28
# Current performance: 0.92857
# Remaining features: ['feature6', 'feature8', 'feature9', 'feature10', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature19', 'feature20', 'feature22', 'feature23', 'feature25', 'feature27', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature19
# Current performance: 0.92857
# Remaining features: ['feature6', 'feature8', 'feature9', 'feature10', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature20', 'feature22', 'feature23', 'feature25', 'feature27', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature8
# Current performance: 0.92857
# Remaining features: ['feature6', 'feature9', 'feature10', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature20', 'feature22', 'feature23', 'feature25', 'feature27', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature42', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature42
# Current performance: 0.92857
# Remaining features: ['feature6', 'feature9', 'feature10', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature20', 'feature22', 'feature23', 'feature25', 'feature27', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature10
# Current performance: 0.92857
# Remaining features: ['feature6', 'feature9', 'feature13', 'feature15', 'feature16', 'feature17', 'feature18', 'feature20', 'feature22', 'feature23', 'feature25', 'feature27', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature13
# Current performance: 0.92857
# Remaining features: ['feature6', 'feature9', 'feature15', 'feature16', 'feature17', 'feature18', 'feature20', 'feature22', 'feature23', 'feature25', 'feature27', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature20
# Current performance: 0.92857
# Remaining features: ['feature6', 'feature9', 'feature15', 'feature16', 'feature17', 'feature18', 'feature22', 'feature23', 'feature25', 'feature27', 'feature29', 'feature30', 'feature31', 'feature32', 'feature34', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature34
# Current performance: 0.95238
# Remaining features: ['feature6', 'feature9', 'feature15', 'feature16', 'feature17', 'feature18', 'feature22', 'feature23', 'feature25', 'feature27', 'feature29', 'feature30', 'feature31', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature15
# Current performance: 0.95238
# Remaining features: ['feature6', 'feature9', 'feature16', 'feature17', 'feature18', 'feature22', 'feature23', 'feature25', 'feature27', 'feature29', 'feature30', 'feature31', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature40', 'feature41', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature40
# Current performance: 0.95238
# Remaining features: ['feature6', 'feature9', 'feature16', 'feature17', 'feature18', 'feature22', 'feature23', 'feature25', 'feature27', 'feature29', 'feature30', 'feature31', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature41', 'feature43', 'feature44', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature44
# Current performance: 0.95238
# Remaining features: ['feature6', 'feature9', 'feature16', 'feature17', 'feature18', 'feature22', 'feature23', 'feature25', 'feature27', 'feature29', 'feature30', 'feature31', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature29
# Current performance: 0.95238
# Remaining features: ['feature6', 'feature9', 'feature16', 'feature17', 'feature18', 'feature22', 'feature23', 'feature25', 'feature27', 'feature30', 'feature31', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature47', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature47
# Current performance: 0.95238
# Remaining features: ['feature6', 'feature9', 'feature16', 'feature17', 'feature18', 'feature22', 'feature23', 'feature25', 'feature27', 'feature30', 'feature31', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature48', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature48
# Current performance: 0.95238
# Remaining features: ['feature6', 'feature9', 'feature16', 'feature17', 'feature18', 'feature22', 'feature23', 'feature25', 'feature27', 'feature30', 'feature31', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature6
# Current performance: 0.95238
# Remaining features: ['feature9', 'feature16', 'feature17', 'feature18', 'feature22', 'feature23', 'feature25', 'feature27', 'feature30', 'feature31', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature25
# Current performance: 0.95238
# Remaining features: ['feature9', 'feature16', 'feature17', 'feature18', 'feature22', 'feature23', 'feature27', 'feature30', 'feature31', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature18
# Current performance: 0.95238
# Remaining features: ['feature9', 'feature16', 'feature17', 'feature22', 'feature23', 'feature27', 'feature30', 'feature31', 'feature32', 'feature36', 'feature37', 'feature38', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature32
# Current performance: 0.92857
# Remaining features: ['feature9', 'feature16', 'feature17', 'feature22', 'feature23', 'feature27', 'feature30', 'feature31', 'feature36', 'feature37', 'feature38', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature23
# Current performance: 0.90476
# Remaining features: ['feature9', 'feature16', 'feature17', 'feature22', 'feature27', 'feature30', 'feature31', 'feature36', 'feature37', 'feature38', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature53', 'feature54', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature54
# Current performance: 0.92857
# Remaining features: ['feature9', 'feature16', 'feature17', 'feature22', 'feature27', 'feature30', 'feature31', 'feature36', 'feature37', 'feature38', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature53', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature27
# Current performance: 0.92857
# Remaining features: ['feature9', 'feature16', 'feature17', 'feature22', 'feature30', 'feature31', 'feature36', 'feature37', 'feature38', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature53', 'feature55', 'feature57', 'feature58', 'feature59', 'feature60']
#
#
# Removed feature: feature60
# Current performance: 0.95238
# Remaining features: ['feature9', 'feature16', 'feature17', 'feature22', 'feature30', 'feature31', 'feature36', 'feature37', 'feature38', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature53', 'feature55', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature55
# Current performance: 0.95238
# Remaining features: ['feature9', 'feature16', 'feature17', 'feature22', 'feature30', 'feature31', 'feature36', 'feature37', 'feature38', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature53', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature38
# Current performance: 0.92857
# Remaining features: ['feature9', 'feature16', 'feature17', 'feature22', 'feature30', 'feature31', 'feature36', 'feature37', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature53', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature53
# Current performance: 0.90476
# Remaining features: ['feature9', 'feature16', 'feature17', 'feature22', 'feature30', 'feature31', 'feature36', 'feature37', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature9
# Current performance: 0.88095
# Remaining features: ['feature16', 'feature17', 'feature22', 'feature30', 'feature31', 'feature36', 'feature37', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature16
# Current performance: 0.90476
# Remaining features: ['feature17', 'feature22', 'feature30', 'feature31', 'feature36', 'feature37', 'feature39', 'feature41', 'feature43', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature43
# Current performance: 0.92857
# Remaining features: ['feature17', 'feature22', 'feature30', 'feature31', 'feature36', 'feature37', 'feature39', 'feature41', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature17
# Current performance: 0.92857
# Remaining features: ['feature22', 'feature30', 'feature31', 'feature36', 'feature37', 'feature39', 'feature41', 'feature45', 'feature46', 'feature49', 'feature50', 'feature52', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature52
# Current performance: 0.90476
# Remaining features: ['feature22', 'feature30', 'feature31', 'feature36', 'feature37', 'feature39', 'feature41', 'feature45', 'feature46', 'feature49', 'feature50', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature39
# Current performance: 0.85714
# Remaining features: ['feature22', 'feature30', 'feature31', 'feature36', 'feature37', 'feature41', 'feature45', 'feature46', 'feature49', 'feature50', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature46
# Current performance: 0.85714
# Remaining features: ['feature22', 'feature30', 'feature31', 'feature36', 'feature37', 'feature41', 'feature45', 'feature49', 'feature50', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature22
# Current performance: 0.80952
# Remaining features: ['feature30', 'feature31', 'feature36', 'feature37', 'feature41', 'feature45', 'feature49', 'feature50', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature41
# Current performance: 0.80952
# Remaining features: ['feature30', 'feature31', 'feature36', 'feature37', 'feature45', 'feature49', 'feature50', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature36
# Current performance: 0.83333
# Remaining features: ['feature30', 'feature31', 'feature37', 'feature45', 'feature49', 'feature50', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature50
# Current performance: 0.85714
# Remaining features: ['feature30', 'feature31', 'feature37', 'feature45', 'feature49', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature37
# Current performance: 0.85714
# Remaining features: ['feature30', 'feature31', 'feature45', 'feature49', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature45
# Current performance: 0.83333
# Remaining features: ['feature30', 'feature31', 'feature49', 'feature57', 'feature58', 'feature59']
#
#
# Removed feature: feature59
# Current performance: 0.83333
# Remaining features: ['feature30', 'feature31', 'feature49', 'feature57', 'feature58']
#
#
# Removed feature: feature57
# Current performance: 0.80952
# Remaining features: ['feature30', 'feature31', 'feature49', 'feature58']
#
#
# Removed feature: feature58
# Current performance: 0.78571
# Remaining features: ['feature30', 'feature31', 'feature49']

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.preprocessing import MinMaxScaler

# %%
def reorder_least_correlated_feature(X, standardize=True, feature_order=None, scaler=None):
    """
    Reorder X based on correlation or a provided feature order.

    Parameters:
    - X: numpy array or pandas DataFrame
    - standardize: bool
    - feature_order: list, optional order from training set (default: None, compute from X)
    - scaler: fitted scaler object (default: None, create new scaler if needed)

    Returns:
    - X_reordered, feature_order (if computed), scaler (if created/used)
    """
    is_dataframe = isinstance(X, pd.DataFrame)
    if is_dataframe:
        column_names = X.columns
        X_np = X.to_numpy()
    else:
        X_np = np.asarray(X)

    # Handle scaling regardless of whether feature_order is provided
    if standardize:
        if scaler is None:
            scaler = MinMaxScaler(feature_range=(-100,100))
            X_scaled = scaler.fit_transform(X_np)
        else:
            X_scaled = scaler.transform(X_np)
    else:
        X_scaled = X_np.copy()
        scaler = None

    # Compute feature order if not provided
    if feature_order is None:
        corr_matrix = np.abs(np.corrcoef(X_scaled, rowvar=False))
        n_features = X_np.shape[1]
        avg_corr = (np.sum(corr_matrix, axis=1) - np.diag(corr_matrix)) / (n_features - 1)
        target_idx = np.argmin(avg_corr)
        feature_order = list(range(n_features))
        feature_order.pop(target_idx)
        feature_order.append(target_idx)

    # Reorder the data (using original data, not scaled)
    if is_dataframe:
        X_reordered = X.iloc[:, feature_order]
    else:
        X_reordered = X_np[:, feature_order]

    return X_reordered, feature_order, scaler

# Usage:
X_train_reordered, feature_order, scaler = reorder_least_correlated_feature(X_train)
X_test_reordered, _, _ = reorder_least_correlated_feature(X_test, feature_order=feature_order, scaler=scaler)

# %%
import numpy as np
from sklearn.base import BaseEstimator, ClassifierMixin
from scipy.interpolate import CubicSpline, PchipInterpolator
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import matplotlib
matplotlib.rcParams['animation.embed_limit'] = 100  # Increase animation size limit

class ImprovedSMPA(BaseEstimator, ClassifierMixin):
    """
    Smooth Manifold Projection Algorithm with improved boundary handling.
    This classifier uses a smooth spline boundary to separate binary classes in 2D.
    """

    def __init__(self, learning_rate=0.005, epochs=50, random_state=7, verbose=False,
                 lambda_scaling='log', patience=5, decay_factor=0.5, min_learning_rate=1e-6,
                 n_control_points=5, smoothing_factor=0.1, spline_type='cubic'):
        """
        Initialize the SMPA classifier.

        Parameters:
        -----------
        learning_rate : float, default=0.005
            Initial learning rate for gradient updates
        epochs : int, default=50
            Maximum number of training epochs
        random_state : int, default=7
            Random seed for reproducibility
        verbose : bool, default=False
            Whether to print progress during training
        lambda_scaling : {'log', 'sqrt', 'none'}, default='log'
            Method to scale the update based on distance
        patience : int, default=5
            Epochs to wait before reducing learning rate
        decay_factor : float, default=0.5
            Factor to reduce learning rate by when patience is exceeded
        min_learning_rate : float, default=1e-6
            Minimum learning rate to stop training
        n_control_points : int, default=5
            Number of control points for the spline
        smoothing_factor : float, default=0.1
            Smoothing parameter for the spline
        spline_type : {'cubic', 'pchip'}, default='cubic'
            Type of spline to use ('pchip' preserves monotonicity better)
        """
        self.learning_rate = learning_rate
        self.initial_learning_rate = learning_rate
        self.epochs = epochs
        self.random_state = random_state
        self.verbose = verbose
        self.lambda_scaling = lambda_scaling
        self.patience = patience
        self.decay_factor = decay_factor
        self.min_learning_rate = min_learning_rate
        self.n_control_points = n_control_points
        self.smoothing_factor = smoothing_factor
        self.spline_type = spline_type

        # Validation
        if lambda_scaling not in ['log', 'sqrt', 'none']:
            raise ValueError("lambda_scaling must be one of 'log', 'sqrt', or 'none'")
        if spline_type not in ['cubic', 'pchip']:
            raise ValueError("spline_type must be one of 'cubic' or 'pchip'")

        # History tracking
        self.error_history_ = []
        self.learning_rate_history_ = []
        self.control_point_history = []
        self.displacement_history = []
        self.error_index_history = []

        # Set random seed
        np.random.seed(random_state)

    def _calculate_class_means(self, X, y):
        """Calculate the mean point for each class."""
        mask_1 = y == 1
        self.m1 = X[mask_1].mean(axis=0)
        self.m0 = X[~mask_1].mean(axis=0)

    def _initialize_control_points(self, X):
        """Initialize control points with improved boundary handling."""
        # Data range with padding to prevent boundary issues
        x_min, x_max = X[:, 0].min(), X[:, 0].max()
        y_min, y_max = X[:, 1].min(), X[:, 1].max()
        x_range = x_max - x_min
        y_range = y_max - y_min

        # Add padding outside data range for better boundary behavior
        x_min_extended = x_min - 0.2 * x_range
        x_max_extended = x_max + 0.2 * x_range

        # Create evenly spaced control points
        self.control_x = np.linspace(x_min_extended, x_max_extended, self.n_control_points)

        # Initialize control y values near the midpoint between class means
        y_mid = (self.m0[1] + self.m1[1]) / 2

        # Add slight randomization but keep endpoints stable
        self.control_y = np.random.uniform(
            y_mid - y_range * 0.05,
            y_mid + y_range * 0.05,
            self.n_control_points
        )

        # Make sure boundary control points have stable derivatives (flatter)
        # This helps prevent the spline from shooting up at the edges
        if self.n_control_points > 2:
            # Set the first and last control points to match second and second-to-last
            self.control_y[0] = self.control_y[1]
            self.control_y[-1] = self.control_y[-2]

        # Store initial control points for visualization
        self.initial_control_x = self.control_x.copy()
        self.initial_control_y = self.control_y.copy()
        self.control_point_history.append((self.control_x.copy(), self.control_y.copy()))

    def _fit_spline(self):
        """Fit a spline to the current control points with boundary constraints."""
        if self.spline_type == 'cubic':
            # Use cubic spline with clamped boundary conditions (zero derivative at endpoints)
            self.spline = CubicSpline(
                self.control_x,
                self.control_y,
                bc_type='clamped'  # This forces zero first derivative at endpoints
            )
        else:  # 'pchip'
            # PCHIP preserves monotonicity and reduces oscillations
            self.spline = PchipInterpolator(self.control_x, self.control_y)

    def _calculate_displacement(self, X):
        """Calculate vertical displacement from the spline."""
        spline_y = self.spline(X[:, 0])
        return X[:, 1] - spline_y

    def _update_pseudo_labels(self, X, y):
        """Determine which side of the spline each class should be on."""
        m1_displacement = self._calculate_displacement(self.m1.reshape(1, -1))[0]
        self.class_1_pseudo = 1 if m1_displacement > 0 else -1
        self.class_0_pseudo = -self.class_1_pseudo
        return np.where(y == 1, self.class_1_pseudo, self.class_0_pseudo)

    def fit(self, X, y):
        """
        Fit the classifier to the training data.

        Parameters:
        -----------
        X : array-like, shape (n_samples, 2)
            Training data
        y : array-like, shape (n_samples,)
            Target values (0 or 1)

        Returns:
        --------
        self : object
            Returns self
        """
        # Validate inputs
        self.classes_ = np.unique(y)
        if not set(self.classes_).issubset({0, 1}):
            raise ValueError("Labels must be 0 and 1")
        if X.shape[1] != 2:
            raise ValueError("This is a 2D-only algorithm for now!")

        X = np.asarray(X)
        y = np.asarray(y)

        # Reset training history
        self.control_point_history = []
        self.displacement_history = []
        self.error_index_history = []
        self.error_history_ = []
        self.learning_rate_history_ = []

        # Initialize
        self._calculate_class_means(X, y)
        self._initialize_control_points(X)
        self._fit_spline()

        # Track best model
        best_error = float('inf')
        best_control_x = None
        best_control_y = None
        best_class_1_pseudo = None

        # Learning rate scheduling
        patience_counter = 0
        current_learning_rate = self.initial_learning_rate

        # Pre-compute class indices for efficient updates
        indices_class_0 = np.where(y == 0)[0]
        indices_class_1 = np.where(y == 1)[0]

        # Main training loop
        for epoch in range(self.epochs):
            # Update spline and calculate errors
            self._fit_spline()
            pseudo_labels = self._update_pseudo_labels(X, y)
            displacements = self._calculate_displacement(X)
            errors = (displacements * pseudo_labels <= 0)
            error_count = np.sum(errors)

            # Store history
            self.error_history_.append(error_count)
            self.learning_rate_history_.append(current_learning_rate)
            self.displacement_history.append(displacements.copy())
            self.error_index_history.append(np.where(errors)[0].copy())

            # Verbose logging
            if self.verbose and epoch % 5 == 0:
                print(f"Epoch {epoch}: Errors = {error_count}, LR = {current_learning_rate:.6f}")

            # Update best model if improved
            if error_count < best_error:
                best_error = error_count
                best_control_x = self.control_x.copy()
                best_control_y = self.control_y.copy()
                best_class_1_pseudo = self.class_1_pseudo
                patience_counter = 0
                self.best_epoch = epoch
            else:
                # Learning rate decay
                patience_counter += 1
                if patience_counter >= self.patience:
                    current_learning_rate = max(current_learning_rate * self.decay_factor, self.min_learning_rate)
                    patience_counter = 0
                    if current_learning_rate == self.min_learning_rate:
                        if self.verbose:
                            print(f"Min learning rate reached at epoch {epoch}")
                        break

            # Update control points based on errors
            if errors.any():
                error_indices = np.where(errors)[0]

                for idx in error_indices:
                    # Get the misclassified point
                    d = X[idx]

                    # Find nearest control point
                    distances = np.abs(self.control_x - d[0])
                    nearest_idx = np.argmin(distances)
                    distance = distances[nearest_idx]

                    # Scale update based on distance
                    if self.lambda_scaling == 'log':
                        lmbda = np.log1p(distance)
                    elif self.lambda_scaling == 'sqrt':
                        lmbda = np.sqrt(distance)
                    else:  # 'none'
                        lmbda = distance

                    # Adaptive margin: higher margins for points far from the decision boundary
                    margin = max(0.1, min(1.0, lmbda * 0.2))

                    # Determine opposite class's correctly classified points
                    if y[idx] == 1:  # Misclassified class 1 point
                        opp_indices = indices_class_0
                    else:  # Misclassified class 0 point
                        opp_indices = indices_class_1

                    # Find correctly classified points in opposite class
                    opp_displacements = displacements[opp_indices]
                    opp_labels = pseudo_labels[opp_indices]
                    correct_opp = opp_indices[opp_displacements * opp_labels > margin]  # Use margin

                    # Calculate step direction
                    if len(correct_opp) > 0:
                        # Pick a random subset of correctly classified opposite class points
                        n_random = max(1, min(len(correct_opp) // 5, 5))  # Take 20%, max 5 points
                        random_correct = np.random.choice(correct_opp, size=n_random, replace=False)

                        # Average position of the random subset
                        random_avg_opp = np.mean(X[random_correct], axis=0)

                        # Calculate step direction toward this average
                        delta_x = random_avg_opp[0] - self.control_x[nearest_idx]
                        delta_y = random_avg_opp[1] - self.control_y[nearest_idx]

                        # Apply step with learning rate
                        step_x = delta_x * current_learning_rate / (1 + lmbda)
                        step_y = delta_y * current_learning_rate / (1 + lmbda)
                    else:
                        # Fallback: Move control point vertically to correct the error
                        step_x = 0
                        step_y = -pseudo_labels[idx] * margin * current_learning_rate

                    # Constrain step_x to maintain ascending order of control points
                    if nearest_idx > 0:
                        min_allowed_x = self.control_x[nearest_idx - 1] + 1e-6
                        max_step_left = self.control_x[nearest_idx] - min_allowed_x
                        step_x = max(step_x, -max_step_left)
                    if nearest_idx < len(self.control_x) - 1:
                        max_allowed_x = self.control_x[nearest_idx + 1] - 1e-6
                        max_step_right = max_allowed_x - self.control_x[nearest_idx]
                        step_x = min(step_x, max_step_right)

                    # Apply updates
                    self.control_x[nearest_idx] += step_x
                    self.control_y[nearest_idx] += step_y

                    # Special handling for boundary control points
                    # Keep first and last control points moving less to prevent boundary issues
                    if nearest_idx == 0 or nearest_idx == len(self.control_x) - 1:
                        # Scale down the step for boundary points
                        self.control_y[nearest_idx] *= 0.7  # Dampen movement at boundaries

                        # If it's the first control point, make second point match the derivative
                        if nearest_idx == 0 and len(self.control_x) > 2:
                            delta = self.control_y[1] - self.control_y[0]
                            self.control_y[0] = self.control_y[1] - 0.5 * delta

                        # If it's the last control point, make second-to-last point match the derivative
                        elif nearest_idx == len(self.control_x) - 1 and len(self.control_x) > 2:
                            delta = self.control_y[-1] - self.control_y[-2]
                            self.control_y[-1] = self.control_y[-2] + 0.5 * delta

            # Store control points after all updates
            self.control_point_history.append((self.control_x.copy(), self.control_y.copy()))

        # Store the last control points from the final epoch
        self.last_control_x = self.control_x.copy()
        self.last_control_y = self.control_y.copy()

        # Restore best model for prediction
        self.control_x = best_control_x
        self.control_y = best_control_y
        self._fit_spline()
        self.class_1_pseudo = best_class_1_pseudo

        return self

    def predict(self, X):
        """
        Predict class labels for samples in X.

        Parameters:
        -----------
        X : array-like, shape (n_samples, 2)
            The input samples

        Returns:
        --------
        y : array-like, shape (n_samples,)
            The predicted classes (0 or 1)
        """
        X = np.asarray(X)
        displacements = self._calculate_displacement(X)
        return np.where(displacements > 0,
                        1 if self.class_1_pseudo > 0 else 0,
                        0 if self.class_1_pseudo > 0 else 1)

    def predict_proba(self, X):
        """
        Estimate probability of each class for samples in X.

        Parameters:
        -----------
        X : array-like, shape (n_samples, 2)
            The input samples

        Returns:
        --------
        proba : array-like, shape (n_samples, 2)
            The class probabilities
        """
        X = np.asarray(X)
        displacements = self._calculate_displacement(X)

        # Convert displacements to probabilities with sigmoid
        def sigmoid(x):
            return 1 / (1 + np.exp(-x))

        # Scale displacement to probability (use absolute displacement as confidence)
        raw_probs = sigmoid(displacements * self.class_1_pseudo * 0.5)

        # Create probability array [p(class=0), p(class=1)]
        if self.class_1_pseudo > 0:
            probs = np.column_stack([1 - raw_probs, raw_probs])
        else:
            probs = np.column_stack([raw_probs, 1 - raw_probs])

        return probs

    def plot_convergence(self, figsize=(12, 5)):
        """Plot error and learning rate history."""
        try:
            import matplotlib.pyplot as plt
            fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)

            # Plot error history
            ax1.plot(self.error_history_, 'b-', label='Errors')
            ax1.set_title('Error Convergence')
            ax1.set_xlabel('Epoch')
            ax1.set_ylabel('Number of Errors')
            ax1.grid(True)

            # Mark the best epoch
            if hasattr(self, 'best_epoch'):
                ax1.axvline(x=self.best_epoch, color='g', linestyle='--',
                            label=f'Best (Epoch {self.best_epoch})')

            # Plot learning rate history
            ax2.plot(self.learning_rate_history_, 'r-', label='Learning Rate')
            ax2.set_title('Learning Rate Decay')
            ax2.set_xlabel('Epoch')
            ax2.set_ylabel('Learning Rate')
            ax2.set_yscale('log')
            ax2.grid(True)

            plt.tight_layout()
            fig.legend()
            return fig
        except ImportError:
            print("Install matplotlib with 'pip install matplotlib'!")
            return None

    def plot_boundary(self, X, y, figsize=(10, 8), padding_factor=0.1):
        """Plot decision boundary and training data."""
        try:
            import matplotlib.pyplot as plt
            import numpy as np
            fig = plt.figure(figsize=figsize)

            # Determine plot ranges
            x_min, x_max = X[:, 0].min(), X[:, 0].max()
            y_min, y_max = X[:, 1].min(), X[:, 1].max()
            x_range = x_max - x_min
            y_range = y_max - y_min

            # Add padding
            x_min -= x_range * padding_factor
            x_max += x_range * padding_factor
            y_min -= y_range * padding_factor
            y_max += y_range * padding_factor

            # Create x-range for spline evaluation
            x_range_points = np.linspace(x_min, x_max, 500)

            # Scatter plot of data points
            plt.scatter(X[:, 0], X[:, 1], c=y, cmap='bwr', alpha=0.6, s=50, zorder=5)

            # Plot initial spline
            if hasattr(self, 'initial_control_x') and hasattr(self, 'initial_control_y'):
                if self.spline_type == 'cubic':
                    initial_spline = CubicSpline(self.initial_control_x, self.initial_control_y, bc_type='clamped')
                else:
                    initial_spline = PchipInterpolator(self.initial_control_x, self.initial_control_y)

                y_initial = initial_spline(x_range_points)
                plt.plot(x_range_points, y_initial, 'r--', label='Initial Boundary', alpha=0.7, zorder=1)

            # Plot best spline
            y_best = self.spline(x_range_points)
            plt.plot(x_range_points, y_best, 'g-', label='Best Boundary', linewidth=2, zorder=2)

            # Plot control points
            plt.scatter(self.initial_control_x, self.initial_control_y,
                        c='orange', marker='o', label='Initial Control Points', alpha=0.7, s=80, zorder=3)
            plt.scatter(self.control_x, self.control_y,
                        c='k', marker='x', label='Best Control Points', s=100, zorder=4)

            # Add class labels
            class0_idx = np.where(y == 0)[0]
            class1_idx = np.where(y == 1)[0]
            class0_center = np.mean(X[class0_idx], axis=0)
            class1_center = np.mean(X[class1_idx], axis=0)

            plt.annotate('Class 0', xy=(class0_center[0], class0_center[1]),
                        xytext=(class0_center[0] + x_range*0.05, class0_center[1] + y_range*0.05),
                        arrowprops=dict(facecolor='black', shrink=0.05, width=1.5),
                        fontsize=12, fontweight='bold')

            plt.annotate('Class 1', xy=(class1_center[0], class1_center[1]),
                        xytext=(class1_center[0] - x_range*0.05, class1_center[1] - y_range*0.05),
                        arrowprops=dict(facecolor='black', shrink=0.05, width=1.5),
                        fontsize=12, fontweight='bold')

            plt.xlim(x_min, x_max)
            plt.ylim(y_min, y_max)
            plt.legend(loc='upper right')
            plt.title(f'ImprovedSMPA Decision Boundary ({self.spline_type} spline)')
            plt.grid(True, linestyle='--', alpha=0.3)

            return fig
        except ImportError:
            print("Install matplotlib with 'pip install matplotlib'!")
            return None

    def animate_training(self, X, y, interval=200, save_path=None,
                     every_nth_epoch=1, figsize=(10, 8), padding_factor=0.1):
        """
        Create an animation of the spline's evolution during training.

        Parameters:
        -----------
        X, y : Training data
        interval : Time between frames in milliseconds
        save_path : If provided, save the animation to this path
        every_nth_epoch : Only show every nth epoch (to reduce animation size)
        figsize : Figure size
        padding_factor : Factor to add padding around the data

        Returns:
        --------
        Animation object that can be displayed in Jupyter/Colab
        """
        try:
            import matplotlib.pyplot as plt
            import matplotlib.animation as animation
            from IPython.display import HTML

            if not self.control_point_history:
                print("No training history found. Run fit() first.")
                return None

            # Set up the figure and axis
            fig, ax = plt.subplots(figsize=figsize)

            # Prepare data ranges with appropriate padding
            x_min, x_max = X[:, 0].min(), X[:, 0].max()
            y_min, y_max = X[:, 1].min(), X[:, 1].max()
            x_range = x_max - x_min
            y_range = y_max - y_min

            x_min -= x_range * padding_factor
            x_max += x_range * padding_factor
            y_min -= y_range * padding_factor
            y_max += y_range * padding_factor

            # Create x-range for spline evaluation
            x_range_points = np.linspace(x_min, x_max, 200)

            # Scatter plot of the data (static)
            scatter = ax.scatter(X[:, 0], X[:, 1], c=y, cmap='bwr', alpha=0.6, s=50, zorder=5)

            # Initialize spline line and control points that will be updated
            spline_line, = ax.plot([], [], 'g-', lw=2, zorder=2)
            control_points = ax.scatter([], [], c='k', marker='x', s=100, zorder=4)

            # Error points highlighting
            error_points = ax.scatter([], [], color='yellow', edgecolor='black',
                                    marker='*', s=150, alpha=0.7, zorder=6)

            # Text for epoch counter and error count
            info_text = ax.text(0.02, 0.95, '', transform=ax.transAxes, fontsize=12,
                            bbox=dict(facecolor='white', alpha=0.7))

            # Set up plot limits and labels
            ax.set_xlim(x_min, x_max)
            ax.set_ylim(y_min, y_max)
            ax.set_title(f'ImprovedSMPA Training Evolution ({self.spline_type} spline)')
            ax.grid(True, linestyle='--', alpha=0.3)

            # Only use a subset of epochs to make the animation manageable
            epochs_to_show = list(range(0, len(self.control_point_history), every_nth_epoch))

            def init():
                spline_line.set_data([], [])
                control_points.set_offsets(np.empty((0, 2)))
                error_points.set_offsets(np.empty((0, 2)))
                info_text.set_text('')
                return spline_line, control_points, error_points, info_text

            def update(frame_idx):
                epoch = epochs_to_show[frame_idx] if frame_idx < len(epochs_to_show) else 0
                if epoch >= len(self.control_point_history):
                    return spline_line, control_points, error_points, info_text

                # Get control points and fit spline
                control_x, control_y = self.control_point_history[epoch]
                try:
                    if self.spline_type == 'cubic':
                        spline = CubicSpline(control_x, control_y, bc_type='clamped')
                    else:
                        spline = PchipInterpolator(control_x, control_y)

                    y_spline = spline(x_range_points)

                    # Handle extreme values
                    mask = np.isfinite(y_spline) & (np.abs(y_spline) < 1e6)
                    if not np.all(mask):
                        # Replace extreme values with something reasonable
                        y_spline = np.clip(y_spline, y_min, y_max)
                        y_spline[~mask] = np.nan  # NaN values won't be plotted

                    # Update spline line
                    spline_line.set_data(x_range_points, y_spline)

                    # Update control points
                    control_points.set_offsets(np.column_stack((control_x, control_y)))

                    # Update error points if we have them
                    if epoch < len(self.error_index_history):
                        error_indices = self.error_index_history[epoch]
                        if len(error_indices) > 0:
                            error_points.set_offsets(X[error_indices])
                        else:
                            error_points.set_offsets(np.empty((0, 2)))

                    # Update info text
                    error_count = self.error_history_[epoch] if epoch < len(self.error_history_) else "N/A"
                    if hasattr(self, 'best_epoch') and epoch == self.best_epoch:
                        info_text.set_text(f'Epoch: {epoch} | Errors: {error_count} | BEST MODEL')
                        info_text.set_bbox(dict(facecolor='lightgreen', alpha=0.7))
                    else:
                        info_text.set_text(f'Epoch: {epoch} | Errors: {error_count}')
                        info_text.set_bbox(dict(facecolor='white', alpha=0.7))
                except Exception as e:
                    print(f"Error in frame {frame_idx} (epoch {epoch}): {e}")
                    # Keep previous state in case of error

                return spline_line, control_points, error_points, info_text

            # Create the animation
            ani = animation.FuncAnimation(fig, update, frames=len(epochs_to_show),
                                        init_func=init, blit=True, interval=interval)

            # Save if requested
            if save_path:
                ani.save(save_path, writer='pillow', dpi=100)
                print(f"Animation saved to {save_path}")

            plt.close(fig)  # Close the figure to avoid displaying it twice
            return ani

        except ImportError as e:
            print(f"Error: {e}. Make sure you have matplotlib installed.")
            return None

# %%
import numpy as np
from sklearn.base import BaseEstimator, ClassifierMixin
from scipy.interpolate import CubicSpline, PchipInterpolator

class NDSMPA(BaseEstimator, ClassifierMixin):
    """
    N-Dimensional Smooth Manifold Projection Algorithm.
    Extends ImprovedSMPA to n dimensions by fitting 2D models for each feature
    against a target feature and combining results additively.
    """

    def __init__(self, learning_rate=0.005, epochs=50, random_state=7, verbose=False,
                 lambda_scaling='log', patience=5, decay_factor=0.5, min_learning_rate=1e-6,
                 n_control_points=5, smoothing_factor=0.1, spline_type='cubic',
                 target_feature=-1, aggregation_method='displacement'):
        """
        Initialize the NDSMPA classifier.

        Parameters:
        -----------
        [Same as ImprovedSMPA parameters]
        target_feature : int, default=-1
            Index of the feature to use as the target dimension (-1 for last feature)
        aggregation_method : {'displacement', 'proba'}, default='displacement'
            Method to aggregate 2D model outputs ('displacement' sums signed displacements,
            'proba' averages probabilities)
        """
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.random_state = random_state
        self.verbose = verbose
        self.lambda_scaling = lambda_scaling
        self.patience = patience
        self.decay_factor = decay_factor
        self.min_learning_rate = min_learning_rate
        self.n_control_points = n_control_points
        self.smoothing_factor = smoothing_factor
        self.spline_type = spline_type
        self.target_feature = target_feature
        self.aggregation_method = aggregation_method

        if aggregation_method not in ['displacement', 'proba']:
            raise ValueError("aggregation_method must be 'displacement' or 'proba'")

        np.random.seed(random_state)
        self.models_ = []  # List to store 2D SMPA models

    def fit(self, X, y):
        """
        Fit the classifier to n-dimensional data.

        Parameters:
        -----------
        X : array-like, shape (n_samples, n_features)
            Training data
        y : array-like, shape (n_samples,)
            Target values (0 or 1)

        Returns:
        --------
        self : object
        """
        X = np.asarray(X)
        y = np.asarray(y)
        n_features = X.shape[1]

        if n_features < 2:
            raise ValueError("Data must have at least 2 features")

        # Validate target_feature
        if self.target_feature >= n_features or self.target_feature < -n_features:
            raise ValueError(f"target_feature must be between {-n_features} and {n_features-1}")
        target_idx = self.target_feature if self.target_feature >= 0 else n_features + self.target_feature

        # Reset models
        self.models_ = []

        # Fit a 2D SMPA model for each feature (except target) paired with target feature
        for feature_idx in range(n_features):
            if feature_idx == target_idx:
                continue
            # Extract 2D subset: [current feature, target feature]
            X_2d = X[:, [feature_idx, target_idx]]

            # Initialize and fit 2D model
            model = ImprovedSMPA(
                learning_rate=self.learning_rate,
                epochs=self.epochs,
                random_state=self.random_state + feature_idx,  # Vary seed for diversity
                verbose=self.verbose,
                lambda_scaling=self.lambda_scaling,
                patience=self.patience,
                decay_factor=self.decay_factor,
                min_learning_rate=self.min_learning_rate,
                n_control_points=self.n_control_points,
                smoothing_factor=self.smoothing_factor,
                spline_type=self.spline_type
            )
            model.fit(X_2d, y)
            self.models_.append(model)

        self.n_features_ = n_features
        self.target_idx_ = target_idx
        return self

    def predict(self, X):
        """
        Predict class labels for samples in X.

        Parameters:
        -----------
        X : array-like, shape (n_samples, n_features)
            The input samples

        Returns:
        --------
        y : array-like, shape (n_samples,)
            The predicted classes (0 or 1)
        """
        X = np.asarray(X)
        if X.shape[1] != self.n_features_:
            raise ValueError(f"Expected {self.n_features_} features, got {X.shape[1]}")

        if self.aggregation_method == 'displacement':
            # Sum signed displacements across all models
            total_displacement = np.zeros(X.shape[0])
            for idx, model in enumerate(self.models_):
                feature_idx = idx if idx < self.target_idx_ else idx + 1  # Adjust for skipped target
                X_2d = X[:, [feature_idx, self.target_idx_]]
                displacements = model._calculate_displacement(X_2d) * model.class_1_pseudo
                total_displacement += displacements
            # Positive total displacement -> class 1, negative -> class 0
            return np.where(total_displacement > 0, 1, 0)
        else:  # 'proba'
            # Average probabilities across all models
            proba = self.predict_proba(X)
            return np.argmax(proba, axis=1)

    def predict_proba(self, X):
        """
        Estimate probability of each class for samples in X.

        Parameters:
        -----------
        X : array-like, shape (n_samples, n_features)
            The input samples

        Returns:
        --------
        proba : array-like, shape (n_samples, 2)
            The class probabilities
        """
        X = np.asarray(X)
        if X.shape[1] != self.n_features_:
            raise ValueError(f"Expected {self.n_features_} features, got {X.shape[1]}")

        # Collect probabilities from all models
        probas = []
        for idx, model in enumerate(self.models_):
            feature_idx = idx if idx < self.target_idx_ else idx + 1
            X_2d = X[:, [feature_idx, self.target_idx_]]
            proba = model.predict_proba(X_2d)
            probas.append(proba)

        # Average probabilities
        mean_proba = np.mean(np.stack(probas, axis=0), axis=0)
        return mean_proba

# %%
param_grid = {
    'learning_rate': [0.001, 0.005, 0.01],           # Learning rate options
    'epochs': [20, 50, 100],                         # Number of epochs
    'n_control_points': [3, 5, 7],                   # Number of spline control points
    'smoothing_factor': [0.05, 0.1, 0.2],            # Smoothing factor for spline
    'aggregation_method': ['displacement', 'proba']  # Aggregation methods
}

# Initialize the base model
base_model = NDSMPA(random_state=7, verbose=False)

# Set up GridSearchCV
grid_search = GridSearchCV(
    estimator=base_model,
    param_grid=param_grid,
    cv=5,                     # 5-fold cross-validation
    scoring='accuracy',       # Optimize for accuracy
    n_jobs=-1,                # Use all available CPU cores
    verbose=1                 # Print progress
)
grid_search.fit(X_train_reordered, y_train)

# Results
print("\nBest parameters found:")
print(grid_search.best_params_)
print(f"Best cross-validation accuracy: {grid_search.best_score_:.4f}")

# Evaluate on test set with best model
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_reordered)
test_accuracy = accuracy_score(y_test, y_pred)
print(f"Test set accuracy with best model: {test_accuracy:.4f}")

print("Classification report: \n")
cr = classification_report(y_test, y_pred)
print(cr)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
#
# Best parameters found:
# {'aggregation_method': 'displacement', 'epochs': 20, 'learning_rate': 0.001, 'n_control_points': 3, 'smoothing_factor': 0.05}
# Best cross-validation accuracy: 0.7166
# Test set accuracy with best model: 0.8095
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79        19
#            1       0.83      0.83      0.83        23
#
#     accuracy                           0.81        42
#    macro avg       0.81      0.81      0.81        42
# weighted avg       0.81      0.81      0.81        42
